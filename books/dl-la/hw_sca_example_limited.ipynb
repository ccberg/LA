# %% [markdown]
# # SCA using hamming weight for classification.
#
# Example from [here]() TODO

# %%
import random

import h5py
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils import shuffle
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *

AES_Sbox = np.array([
    
])


# labelize for key guesess for guessing entropy and success rate
def aes_labelize_ge_sr(plt_attack, byte, key, leakage):
    pt_ct = [row[byte] for row in plt_attack]

    key_byte = np.full(len(pt_ct), key[byte])
    state = [int(x) ^ int(k) for x, k in zip(np.asarray(pt_ct[:]), key_byte)]

    intermediate_values = AES_Sbox[state]

    if leakage == "HW":
        return [bin(iv).count("1") for iv in intermediate_values]
    else:
        return intermediate_values


def aes_labelize(trace_data, byte, leakage_model):
    pt_ct = [row[byte] for row in trace_data]

    key_byte = [row[byte + 16] for row in trace_data]
    key_byte = np.asarray(key_byte[:])

    state = [int(x) ^ int(k) for x, k in zip(np.asarray(pt_ct[:]), key_byte)]

    intermediate_values = AES_Sbox[state]

    if leakage_model == "HW":
        return [bin(iv).count("1") for iv in intermediate_values]
    else:
        return intermediate_values


def load_dataset(dataset_file, n_profiling, n_attack, target_byte, leakage_model):
    in_file = h5py.File(dataset_file, "r")
    profiling_samples = np.array(in_file['Profiling_traces/traces'], dtype=np.float64)
    attack_samples = np.array(in_file['Attack_traces/traces'], dtype=np.float64)
    profiling_plaintext = in_file['Profiling_traces/metadata']['plaintext']
    attack_plaintext = in_file['Attack_traces/metadata']['plaintext']
    profiling_key = in_file['Profiling_traces/metadata']['key']
    attack_key = in_file['Attack_traces/metadata']['key']
    profiling_data = np.zeros((n_profiling, 32))
    attack_data = np.zeros((n_attack, 32))
    for i in range(n_profiling):
        profiling_data[i][0:16] = profiling_plaintext[i]
        profiling_data[i][16:32] = profiling_key[i]

    for i in range(n_attack):
        attack_data[i][0:16] = attack_plaintext[i]
        attack_data[i][16:32] = attack_key[i]

    nt = n_profiling
    na = n_attack

    X_profiling = profiling_samples[0:nt]
    Y_profiling = aes_labelize(profiling_data[0:nt], target_byte, leakage_model)
    X_attack = attack_samples[0:na]
    Y_attack = aes_labelize(attack_data[0:na], target_byte, leakage_model)

    return (X_profiling, Y_profiling), (X_attack, Y_attack), (profiling_data, attack_data)


def create_z_score_norm(dataset):
    z_score_mean = np.mean(dataset, axis=0)
    z_score_std = np.std(dataset, axis=0)
    return z_score_mean, z_score_std


def apply_z_score_norm(dataset, z_score_mean, z_score_std):
    for index in range(len(dataset)):
        dataset[index] = (dataset[index] - z_score_mean) / z_score_std


# guessing entropy and success rate
def compute_ge(runs, model, key, correct_key, leakage_model, byte, x_attack, plt_attack, key_rank_report_interval, key_rank_attack_traces):
    nt = len(x_attack)
    nt_interval = int(key_rank_attack_traces / key_rank_report_interval)
    key_ranking_sum = np.zeros(nt_interval)

    # ---------------------------------------------------------------------------------------------------------#
    # compute labels for key hypothesis
    # ---------------------------------------------------------------------------------------------------------#
    labels_key_hypothesis = np.zeros((256, nt))
    for key_byte_hypothesis in range(0, 256):
        key_h = bytearray.fromhex(key)
        key_h[byte] = key_byte_hypothesis
        labels_key_hypothesis[key_byte_hypothesis][:] = aes_labelize_ge_sr(plt_attack, byte, key_h, leakage_model)

    # ---------------------------------------------------------------------------------------------------------#
    # predict output probabilities for shuffled test or validation set
    # ---------------------------------------------------------------------------------------------------------#
    output_probabilities = model.predict(x_attack)

    probabilities_kg_all_traces = np.zeros((nt, 256))
    for index in range(nt):
        probabilities_kg_all_traces[index] = output_probabilities[index][
            np.asarray([int(leakage[index]) for leakage in labels_key_hypothesis[:]])
        ]

    # ---------------------------------------------------------------------------------------------------------#
    # run key rank "runs" times and average results.
    # ---------------------------------------------------------------------------------------------------------#
    for run in range(runs):

        probabilities_kg_all_traces_shuffled = shuffle(probabilities_kg_all_traces,
                                                       random_state=random.randint(0, 100000))

        key_probabilities = np.zeros(256)

        kr_count = 0
        for index in range(key_rank_attack_traces):

            key_probabilities += np.log(probabilities_kg_all_traces_shuffled[index] + 1e-36)
            key_probabilities_sorted = np.argsort(key_probabilities)[::-1]

            if (index + 1) % key_rank_report_interval == 0:
                key_ranking_good_key = list(key_probabilities_sorted).index(correct_key) + 1
                key_ranking_sum[kr_count] += key_ranking_good_key
                kr_count += 1

        print("KR run: {} | final GE for correct key ({}): {})".format(run, correct_key, key_ranking_sum[nt_interval - 1] / (run + 1)))

    guessing_entropy = key_ranking_sum / runs

    return guessing_entropy


def mlp(classes, number_of_samples):
    model = Sequential()
    model.add(Dense(200, activation='relu', input_shape=(number_of_samples,)))
    model.add(Dense(200, activation='relu', input_shape=(number_of_samples,)))
    model.add(Dense(200, activation='relu', input_shape=(number_of_samples,)))
    model.add(Dense(200, activation='relu', input_shape=(number_of_samples,)))
    model.add(Dense(classes, activation='softmax'))
    model.summary()
    optimizer = Adam(lr=0.001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
poi = (187, 203)

l_model = "HW"
classes = 9
target_byte = 2
n_profiling = 200000
n_attack = 100000
correct_key = 34
key = "00112233445566778899AABBCCDDEEFF"

ASCAD_data_folder = "/data/ASCAD/ATMEGA_AES_v1/ATM_AES_v1_variable_key/ASCAD_data/ASCAD_databases/"

# Load the profiling traces
(X_profiling, _), (X_attack, _), (profiling_data, attack_data) = load_dataset(
    ASCAD_data_folder + "ASCAD_variable.h5",
    n_profiling, n_attack, target_byte, l_model)

X_profiling = X_profiling[:, poi[0]:poi[1]]
X_attack = X_attack[:, poi[0]:poi[1]]
ns = poi[1] - poi[0]

# normalize with z-score
z_score_mean, z_score_std = create_z_score_norm(X_profiling)
apply_z_score_norm(X_profiling, z_score_mean, z_score_std)
apply_z_score_norm(X_attack, z_score_mean, z_score_std)

X_profiling = X_profiling.astype('float32')
X_attack = X_attack.astype('float32')

# labelize according to leakage model (in this case, HW of byte 0 of S-box out on first AES encryption round)
profiling_labels = aes_labelize(profiling_data, target_byte, l_model)
attack_labels = aes_labelize(attack_data, target_byte, l_model)

# convert labels to categorical labels
Y_profiling = to_categorical(profiling_labels, num_classes=classes)
Y_attack = to_categorical(attack_labels, num_classes=classes)

key_rank_report_interval = 1
key_rank_number_of_traces = 17500
key_rank_runs = 100

# train MLP
model = mlp(classes, ns)

# reshape if needed
input_layer_shape = model.get_layer(index=0).input_shape
if len(input_layer_shape) == 3:
    X_profiling = X_profiling.reshape((X_profiling.shape[0], X_profiling.shape[1], 1))
    X_attack = X_attack.reshape((X_attack.shape[0], X_attack.shape[1], 1))
else:
    X_profiling = X_profiling
    X_attack = X_attack
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_55 (Dense)             (None, 200)               3400
# _________________________________________________________________
# dense_56 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dense_57 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dense_58 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dense_59 (Dense)             (None, 9)                 1809
# =================================================================
# Total params: 125,809
# Trainable params: 125,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
sum(np.argmax(Y_profiling, axis=1)[:100])
# np.argmax(Y_attack, axis=1)
# Out:
# 394

# %%
model.fit(
    x=X_profiling,
    y=Y_profiling,
    batch_size=150,
    verbose=1,
    epochs=10,
    shuffle=True,
    validation_data=(X_attack, Y_attack),
    callbacks=[])
# Out:
# Epoch 1/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.7831 - accuracy: 0.2684 - val_loss: 1.7623 - val_accuracy: 0.2727
# Epoch 2/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7661 - accuracy: 0.2712 - val_loss: 1.7612 - val_accuracy: 0.2727
# Epoch 3/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7645 - accuracy: 0.2735 - val_loss: 1.7622 - val_accuracy: 0.2728
# Epoch 4/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7650 - accuracy: 0.2718 - val_loss: 1.7612 - val_accuracy: 0.2727
# Epoch 5/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7614 - accuracy: 0.2734 - val_loss: 1.7611 - val_accuracy: 0.2727
# Epoch 6/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7621 - accuracy: 0.2741 - val_loss: 1.7613 - val_accuracy: 0.2727
# Epoch 7/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7622 - accuracy: 0.2729 - val_loss: 1.7610 - val_accuracy: 0.2727
# Epoch 8/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7625 - accuracy: 0.2728 - val_loss: 1.7616 - val_accuracy: 0.2727
# Epoch 9/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7647 - accuracy: 0.2721 - val_loss: 1.7607 - val_accuracy: 0.2727
# Epoch 10/10
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.7646 - accuracy: 0.2735 - val_loss: 1.7612 - val_accuracy: 0.2727

# %%
ge = compute_ge(key_rank_runs, model, key, correct_key, l_model, target_byte, X_attack, attack_data, key_rank_report_interval,
                key_rank_number_of_traces)

plt.plot(np.arange(1, key_rank_number_of_traces + 1), ge, label="GE")
plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.xlim([0, key_rank_number_of_traces])
plt.legend()
plt.show()
# Out:
# KR run: 0 | final GE for correct key (34): 7.0)
# KR run: 1 | final GE for correct key (34): 94.0)
# KR run: 2 | final GE for correct key (34): 68.66666666666667)
# KR run: 3 | final GE for correct key (34): 98.0)
# KR run: 4 | final GE for correct key (34): 78.6)
# KR run: 5 | final GE for correct key (34): 66.5)
# KR run: 6 | final GE for correct key (34): 66.57142857142857)
# KR run: 7 | final GE for correct key (34): 76.5)
# KR run: 8 | final GE for correct key (34): 92.66666666666667)
# KR run: 9 | final GE for correct key (34): 92.8)
# KR run: 10 | final GE for correct key (34): 87.54545454545455)
# KR run: 11 | final GE for correct key (34): 86.66666666666667)
# KR run: 12 | final GE for correct key (34): 85.38461538461539)
# KR run: 13 | final GE for correct key (34): 87.28571428571429)
# KR run: 14 | final GE for correct key (34): 89.53333333333333)
# KR run: 15 | final GE for correct key (34): 86.875)
# KR run: 16 | final GE for correct key (34): 85.05882352941177)
# KR run: 17 | final GE for correct key (34): 80.44444444444444)
# KR run: 18 | final GE for correct key (34): 76.73684210526316)
# KR run: 19 | final GE for correct key (34): 82.3)
# KR run: 20 | final GE for correct key (34): 80.52380952380952)
# KR run: 21 | final GE for correct key (34): 78.4090909090909)
# KR run: 22 | final GE for correct key (34): 80.3913043478261)
# KR run: 23 | final GE for correct key (34): 79.25)
# KR run: 24 | final GE for correct key (34): 76.12)
# KR run: 25 | final GE for correct key (34): 77.23076923076923)
# KR run: 26 | final GE for correct key (34): 75.07407407407408)
# KR run: 27 | final GE for correct key (34): 72.78571428571429)
# KR run: 28 | final GE for correct key (34): 73.24137931034483)
# KR run: 29 | final GE for correct key (34): 77.5)
# KR run: 30 | final GE for correct key (34): 79.3225806451613)
# KR run: 31 | final GE for correct key (34): 79.0625)
# KR run: 32 | final GE for correct key (34): 81.45454545454545)
# KR run: 33 | final GE for correct key (34): 79.44117647058823)
# KR run: 34 | final GE for correct key (34): 80.54285714285714)
# KR run: 35 | final GE for correct key (34): 82.5)
# KR run: 36 | final GE for correct key (34): 81.86486486486487)
# KR run: 37 | final GE for correct key (34): 81.55263157894737)
# KR run: 38 | final GE for correct key (34): 80.25641025641026)
# KR run: 39 | final GE for correct key (34): 80.25)
# KR run: 40 | final GE for correct key (34): 78.6829268292683)
# KR run: 41 | final GE for correct key (34): 80.47619047619048)
# KR run: 42 | final GE for correct key (34): 80.86046511627907)
# KR run: 43 | final GE for correct key (34): 80.45454545454545)
# KR run: 44 | final GE for correct key (34): 79.28888888888889)
# KR run: 45 | final GE for correct key (34): 80.04347826086956)
# KR run: 46 | final GE for correct key (34): 80.80851063829788)
# KR run: 47 | final GE for correct key (34): 82.29166666666667)
# KR run: 48 | final GE for correct key (34): 82.71428571428571)
# KR run: 49 | final GE for correct key (34): 81.62)
# KR run: 50 | final GE for correct key (34): 80.17647058823529)
# KR run: 51 | final GE for correct key (34): 82.0)
# KR run: 52 | final GE for correct key (34): 82.83018867924528)
# KR run: 53 | final GE for correct key (34): 85.03703703703704)
# KR run: 54 | final GE for correct key (34): 83.56363636363636)
# KR run: 55 | final GE for correct key (34): 83.66071428571429)
# KR run: 56 | final GE for correct key (34): 82.7719298245614)
# KR run: 57 | final GE for correct key (34): 81.53448275862068)
# KR run: 58 | final GE for correct key (34): 81.47457627118644)
# KR run: 59 | final GE for correct key (34): 80.35)
# KR run: 60 | final GE for correct key (34): 79.85245901639344)
# KR run: 61 | final GE for correct key (34): 80.69354838709677)
# KR run: 62 | final GE for correct key (34): 82.60317460317461)
# KR run: 63 | final GE for correct key (34): 82.359375)
# KR run: 64 | final GE for correct key (34): 81.33846153846154)
# KR run: 65 | final GE for correct key (34): 80.93939393939394)
# KR run: 66 | final GE for correct key (34): 81.19402985074628)
# KR run: 67 | final GE for correct key (34): 80.11764705882354)
# KR run: 68 | final GE for correct key (34): 79.08695652173913)
# KR run: 69 | final GE for correct key (34): 80.05714285714286)
# KR run: 70 | final GE for correct key (34): 79.1830985915493)
# KR run: 71 | final GE for correct key (34): 78.375)
# KR run: 72 | final GE for correct key (34): 79.41095890410959)
# KR run: 73 | final GE for correct key (34): 79.37837837837837)
# KR run: 74 | final GE for correct key (34): 78.8)
# KR run: 75 | final GE for correct key (34): 79.53947368421052)
# KR run: 76 | final GE for correct key (34): 78.55844155844156)
# KR run: 77 | final GE for correct key (34): 77.65384615384616)
# KR run: 78 | final GE for correct key (34): 78.44303797468355)
# KR run: 79 | final GE for correct key (34): 79.6875)
# KR run: 80 | final GE for correct key (34): 79.80246913580247)
# KR run: 81 | final GE for correct key (34): 79.79268292682927)
# KR run: 82 | final GE for correct key (34): 79.09638554216868)
# KR run: 83 | final GE for correct key (34): 79.17857142857143)
# KR run: 84 | final GE for correct key (34): 78.32941176470588)
# KR run: 85 | final GE for correct key (34): 77.5813953488372)
# KR run: 86 | final GE for correct key (34): 79.08045977011494)
# KR run: 87 | final GE for correct key (34): 78.6590909090909)
# KR run: 88 | final GE for correct key (34): 79.69662921348315)
# KR run: 89 | final GE for correct key (34): 79.6)
# KR run: 90 | final GE for correct key (34): 78.9010989010989)
# KR run: 91 | final GE for correct key (34): 80.05434782608695)
# KR run: 92 | final GE for correct key (34): 79.35483870967742)
# KR run: 93 | final GE for correct key (34): 80.2127659574468)
# KR run: 94 | final GE for correct key (34): 79.37894736842105)
# KR run: 95 | final GE for correct key (34): 79.97916666666667)
# KR run: 96 | final GE for correct key (34): 79.77319587628865)
# KR run: 97 | final GE for correct key (34): 79.88775510204081)
# KR run: 98 | final GE for correct key (34): 80.41414141414141)
# KR run: 99 | final GE for correct key (34): 79.68)

# %%
import seaborn as sns
from src.tools.plotter import init_plots

init_plots()

G = sns.lineplot(data={"GE": ge})
G.set(ylabel="Guessing entropy 3rd byte", xlabel="Number of traces")
G2 = sns.lineplot(data={"Random guessing": np.ones_like(ge) * 128}, palette=[sns.color_palette()[3]], dashes=[(2, 2)])
