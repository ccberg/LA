# %%
import numpy as np
import seaborn as sns

from src.tools.plotter import init_plots

init_plots()

# %%
IXS = np.arange(0, 3000, 700)
PVS = np.arange(len(IXS))
TARGET_IXS = np.arange(max(IXS) + 700)

sns.lineplot(data=np.interp(TARGET_IXS, IXS, PVS))
# Out:
# <AxesSubplot:>
