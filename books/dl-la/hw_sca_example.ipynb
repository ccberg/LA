# %% [markdown]
# # SCA using hamming weight for classification.
#
# Example from [here]() TODO

# %%
import random

import h5py
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils import shuffle
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *

AES_Sbox = np.array([
    
])


# labelize for key guesess for guessing entropy and success rate
def aes_labelize_ge_sr(plt_attack, byte, key, leakage):
    pt_ct = [row[byte] for row in plt_attack]

    key_byte = np.full(len(pt_ct), key[byte])
    state = [int(x) ^ int(k) for x, k in zip(np.asarray(pt_ct[:]), key_byte)]

    intermediate_values = AES_Sbox[state]

    if leakage == "HW":
        return [bin(iv).count("1") for iv in intermediate_values]
    else:
        return intermediate_values


def aes_labelize(trace_data, byte, leakage_model):
    pt_ct = [row[byte] for row in trace_data]

    key_byte = [row[byte + 16] for row in trace_data]
    key_byte = np.asarray(key_byte[:])

    state = [int(x) ^ int(k) for x, k in zip(np.asarray(pt_ct[:]), key_byte)]

    intermediate_values = AES_Sbox[state]

    if leakage_model == "HW":
        return [bin(iv).count("1") for iv in intermediate_values]
    else:
        return intermediate_values


def load_dataset(dataset_file, n_profiling, n_attack, target_byte, leakage_model):
    in_file = h5py.File(dataset_file, "r")
    profiling_samples = np.array(in_file['Profiling_traces/traces'], dtype=np.float64)
    attack_samples = np.array(in_file['Attack_traces/traces'], dtype=np.float64)
    profiling_plaintext = in_file['Profiling_traces/metadata']['plaintext']
    attack_plaintext = in_file['Attack_traces/metadata']['plaintext']
    profiling_key = in_file['Profiling_traces/metadata']['key']
    attack_key = in_file['Attack_traces/metadata']['key']
    profiling_data = np.zeros((n_profiling, 32))
    attack_data = np.zeros((n_attack, 32))
    for i in range(n_profiling):
        profiling_data[i][0:16] = profiling_plaintext[i]
        profiling_data[i][16:32] = profiling_key[i]

    for i in range(n_attack):
        attack_data[i][0:16] = attack_plaintext[i]
        attack_data[i][16:32] = attack_key[i]

    nt = n_profiling
    na = n_attack

    X_profiling = profiling_samples[0:nt]
    Y_profiling = aes_labelize(profiling_data[0:nt], target_byte, leakage_model)
    X_attack = attack_samples[0:na]
    Y_attack = aes_labelize(attack_data[0:na], target_byte, leakage_model)

    return (X_profiling, Y_profiling), (X_attack, Y_attack), (profiling_data, attack_data)


def create_z_score_norm(dataset):
    z_score_mean = np.mean(dataset, axis=0)
    z_score_std = np.std(dataset, axis=0)
    return z_score_mean, z_score_std


def apply_z_score_norm(dataset, z_score_mean, z_score_std):
    for index in range(len(dataset)):
        dataset[index] = (dataset[index] - z_score_mean) / z_score_std


# guessing entropy and success rate
def compute_ge(runs, model, key, correct_key, leakage_model, byte, x_attack, plt_attack, key_rank_report_interval, key_rank_attack_traces):
    nt = len(x_attack)
    nt_interval = int(key_rank_attack_traces / key_rank_report_interval)
    key_ranking_sum = np.zeros(nt_interval)

    # ---------------------------------------------------------------------------------------------------------#
    # compute labels for key hypothesis
    # ---------------------------------------------------------------------------------------------------------#
    labels_key_hypothesis = np.zeros((256, nt))
    for key_byte_hypothesis in range(0, 256):
        key_h = bytearray.fromhex(key)
        key_h[byte] = key_byte_hypothesis
        labels_key_hypothesis[key_byte_hypothesis][:] = aes_labelize_ge_sr(plt_attack, byte, key_h, leakage_model)

    # ---------------------------------------------------------------------------------------------------------#
    # predict output probabilities for shuffled test or validation set
    # ---------------------------------------------------------------------------------------------------------#
    output_probabilities = model.predict(x_attack)

    probabilities_kg_all_traces = np.zeros((nt, 256))
    for index in range(nt):
        probabilities_kg_all_traces[index] = output_probabilities[index][
            np.asarray([int(leakage[index]) for leakage in labels_key_hypothesis[:]])
        ]

    # ---------------------------------------------------------------------------------------------------------#
    # run key rank "runs" times and average results.
    # ---------------------------------------------------------------------------------------------------------#
    for run in range(runs):

        probabilities_kg_all_traces_shuffled = shuffle(probabilities_kg_all_traces,
                                                       random_state=random.randint(0, 100000))

        key_probabilities = np.zeros(256)

        kr_count = 0
        for index in range(key_rank_attack_traces):

            key_probabilities += np.log(probabilities_kg_all_traces_shuffled[index] + 1e-36)
            key_probabilities_sorted = np.argsort(key_probabilities)[::-1]

            if (index + 1) % key_rank_report_interval == 0:
                key_ranking_good_key = list(key_probabilities_sorted).index(correct_key) + 1
                key_ranking_sum[kr_count] += key_ranking_good_key
                kr_count += 1

        print("KR run: {} | final GE for correct key ({}): {})".format(run, correct_key, key_ranking_sum[nt_interval - 1] / (run + 1)))

    guessing_entropy = key_ranking_sum / runs

    return guessing_entropy


def mlp(classes, number_of_samples):
    model = Sequential()
    model.add(Dense(200, activation='relu', input_shape=(number_of_samples,)))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(classes, activation='softmax'))
    model.summary()
    optimizer = Adam(lr=0.001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
l_model = "HW"
classes = 9
target_byte = 2
n_profiling = 200000
n_attack = 10000
ns = 1400
correct_key = 34
key = "00112233445566778899AABBCCDDEEFF"

ASCAD_data_folder = "/data/ASCAD/ATMEGA_AES_v1/ATM_AES_v1_variable_key/ASCAD_data/ASCAD_databases/"

# Load the profiling traces
(X_profiling, _), (X_attack, _), (profiling_data, attack_data) = load_dataset(
    ASCAD_data_folder + "ASCAD_variable.h5",
    n_profiling, n_attack, target_byte, l_model)

# normalize with z-score
z_score_mean, z_score_std = create_z_score_norm(X_profiling)
apply_z_score_norm(X_profiling, z_score_mean, z_score_std)
apply_z_score_norm(X_attack, z_score_mean, z_score_std)

X_profiling = X_profiling.astype('float32')
X_attack = X_attack.astype('float32')

# labelize according to leakage model (in this case, HW of byte 0 of S-box out on first AES encryption round)
profiling_labels = aes_labelize(profiling_data, target_byte, l_model)
attack_labels = aes_labelize(attack_data, target_byte, l_model)

# convert labels to categorical labels
Y_profiling = to_categorical(profiling_labels, num_classes=classes)
Y_attack = to_categorical(attack_labels, num_classes=classes)

key_rank_report_interval = 1
key_rank_number_of_traces = 1000
key_rank_runs = 100

# train MLP
model = mlp(classes, ns)

# reshape if needed
input_layer_shape = model.get_layer(index=0).input_shape
if len(input_layer_shape) == 3:
    X_profiling = X_profiling.reshape((X_profiling.shape[0], X_profiling.shape[1], 1))
    X_attack = X_attack.reshape((X_attack.shape[0], X_attack.shape[1], 1))
else:
    X_profiling = X_profiling
    X_attack = X_attack
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 200)               280200
# _________________________________________________________________
# dense_6 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dense_7 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dense_8 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dense_9 (Dense)              (None, 9)                 1809
# =================================================================
# Total params: 402,609
# Trainable params: 402,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
sum(np.argmax(Y_profiling, axis=1)[:100])
# np.argmax(Y_attack, axis=1)
# Out:
# 394

# %%
model.fit(
    x=X_profiling,
    y=Y_profiling,
    batch_size=150,
    verbose=1,
    epochs=10,
    shuffle=True,
    validation_data=(X_attack, Y_attack),
    callbacks=[])
# Out:
# Epoch 1/10
# 1334/1334 [==============================] - 4s 3ms/step - loss: 1.7911 - accuracy: 0.2613 - val_loss: 1.7513 - val_accuracy: 0.2790
# Epoch 2/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.7531 - accuracy: 0.2714 - val_loss: 1.7372 - val_accuracy: 0.2826
# Epoch 3/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.7327 - accuracy: 0.2747 - val_loss: 1.7357 - val_accuracy: 0.2853
# Epoch 4/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.7221 - accuracy: 0.2790 - val_loss: 1.7356 - val_accuracy: 0.2829
# Epoch 5/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.7070 - accuracy: 0.2825 - val_loss: 1.7183 - val_accuracy: 0.2830
# Epoch 6/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.6952 - accuracy: 0.2841 - val_loss: 1.7198 - val_accuracy: 0.2849
# Epoch 7/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.6870 - accuracy: 0.2846 - val_loss: 1.7248 - val_accuracy: 0.2868
# Epoch 8/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.6748 - accuracy: 0.2883 - val_loss: 1.7272 - val_accuracy: 0.2842
# Epoch 9/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.6630 - accuracy: 0.2889 - val_loss: 1.7334 - val_accuracy: 0.2831
# Epoch 10/10
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.6494 - accuracy: 0.2946 - val_loss: 1.7405 - val_accuracy: 0.2831

# %%
ge = compute_ge(key_rank_runs, model, key, correct_key, l_model, target_byte, X_attack, attack_data, key_rank_report_interval,
                key_rank_number_of_traces)

plt.plot(np.arange(1, key_rank_number_of_traces + 1), ge, label="GE")
plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.xlim([0, key_rank_number_of_traces])
plt.legend()
plt.show()
# Out:
# KR run: 0 | final GE for correct key (34): 1.0)
# KR run: 1 | final GE for correct key (34): 1.0)
# KR run: 2 | final GE for correct key (34): 1.0)
# KR run: 3 | final GE for correct key (34): 1.0)
# KR run: 4 | final GE for correct key (34): 1.0)
# KR run: 5 | final GE for correct key (34): 1.0)
# KR run: 6 | final GE for correct key (34): 1.0)
# KR run: 7 | final GE for correct key (34): 1.0)
# KR run: 8 | final GE for correct key (34): 1.0)
# KR run: 9 | final GE for correct key (34): 1.0)
# KR run: 10 | final GE for correct key (34): 1.0)
# KR run: 11 | final GE for correct key (34): 1.0)
# KR run: 12 | final GE for correct key (34): 1.0)
# KR run: 13 | final GE for correct key (34): 1.0)
# KR run: 14 | final GE for correct key (34): 1.0)
# KR run: 15 | final GE for correct key (34): 1.0)
# KR run: 16 | final GE for correct key (34): 1.0)
# KR run: 17 | final GE for correct key (34): 1.0)
# KR run: 18 | final GE for correct key (34): 1.0)
# KR run: 19 | final GE for correct key (34): 1.0)
# KR run: 20 | final GE for correct key (34): 1.0)
# KR run: 21 | final GE for correct key (34): 1.0)
# KR run: 22 | final GE for correct key (34): 1.0)
# KR run: 23 | final GE for correct key (34): 1.0)
# KR run: 24 | final GE for correct key (34): 1.0)
# KR run: 25 | final GE for correct key (34): 1.0)
# KR run: 26 | final GE for correct key (34): 1.0)
# KR run: 27 | final GE for correct key (34): 1.0)
# KR run: 28 | final GE for correct key (34): 1.0)
# KR run: 29 | final GE for correct key (34): 1.0)
# KR run: 30 | final GE for correct key (34): 1.0)
# KR run: 31 | final GE for correct key (34): 1.0)
# KR run: 32 | final GE for correct key (34): 1.0)
# KR run: 33 | final GE for correct key (34): 1.0)
# KR run: 34 | final GE for correct key (34): 1.0)
# KR run: 35 | final GE for correct key (34): 1.0)
# KR run: 36 | final GE for correct key (34): 1.0)
# KR run: 37 | final GE for correct key (34): 1.0)
# KR run: 38 | final GE for correct key (34): 1.0)
# KR run: 39 | final GE for correct key (34): 1.0)
# KR run: 40 | final GE for correct key (34): 1.0)
# KR run: 41 | final GE for correct key (34): 1.0)
# KR run: 42 | final GE for correct key (34): 1.0)
# KR run: 43 | final GE for correct key (34): 1.0)
# KR run: 44 | final GE for correct key (34): 1.0)
# KR run: 45 | final GE for correct key (34): 1.0)
# KR run: 46 | final GE for correct key (34): 1.0)
# KR run: 47 | final GE for correct key (34): 1.0)
# KR run: 48 | final GE for correct key (34): 1.0)
# KR run: 49 | final GE for correct key (34): 1.0)
# KR run: 50 | final GE for correct key (34): 1.0)
# KR run: 51 | final GE for correct key (34): 1.0)
# KR run: 52 | final GE for correct key (34): 1.0)
# KR run: 53 | final GE for correct key (34): 1.0)
# KR run: 54 | final GE for correct key (34): 1.0)
# KR run: 55 | final GE for correct key (34): 1.0)
# KR run: 56 | final GE for correct key (34): 1.0)
# KR run: 57 | final GE for correct key (34): 1.0)
# KR run: 58 | final GE for correct key (34): 1.0)
# KR run: 59 | final GE for correct key (34): 1.0)
# KR run: 60 | final GE for correct key (34): 1.0)
# KR run: 61 | final GE for correct key (34): 1.0)
# KR run: 62 | final GE for correct key (34): 1.0)
# KR run: 63 | final GE for correct key (34): 1.0)
# KR run: 64 | final GE for correct key (34): 1.0)
# KR run: 65 | final GE for correct key (34): 1.0)
# KR run: 66 | final GE for correct key (34): 1.0)
# KR run: 67 | final GE for correct key (34): 1.0)
# KR run: 68 | final GE for correct key (34): 1.0)
# KR run: 69 | final GE for correct key (34): 1.0)
# KR run: 70 | final GE for correct key (34): 1.0)
# KR run: 71 | final GE for correct key (34): 1.0)
# KR run: 72 | final GE for correct key (34): 1.0)
# KR run: 73 | final GE for correct key (34): 1.0)
# KR run: 74 | final GE for correct key (34): 1.0)
# KR run: 75 | final GE for correct key (34): 1.0)
# KR run: 76 | final GE for correct key (34): 1.0)
# KR run: 77 | final GE for correct key (34): 1.0)
# KR run: 78 | final GE for correct key (34): 1.0)
# KR run: 79 | final GE for correct key (34): 1.0)
# KR run: 80 | final GE for correct key (34): 1.0)
# KR run: 81 | final GE for correct key (34): 1.0)
# KR run: 82 | final GE for correct key (34): 1.0)
# KR run: 83 | final GE for correct key (34): 1.0)
# KR run: 84 | final GE for correct key (34): 1.0)
# KR run: 85 | final GE for correct key (34): 1.0)
# KR run: 86 | final GE for correct key (34): 1.0)
# KR run: 87 | final GE for correct key (34): 1.0)
# KR run: 88 | final GE for correct key (34): 1.0)
# KR run: 89 | final GE for correct key (34): 1.0)
# KR run: 90 | final GE for correct key (34): 1.0)
# KR run: 91 | final GE for correct key (34): 1.0)
# KR run: 92 | final GE for correct key (34): 1.0)
# KR run: 93 | final GE for correct key (34): 1.0)
# KR run: 94 | final GE for correct key (34): 1.0)
# KR run: 95 | final GE for correct key (34): 1.0)
# KR run: 96 | final GE for correct key (34): 1.0)
# KR run: 97 | final GE for correct key (34): 1.0)
# KR run: 98 | final GE for correct key (34): 1.0)
# KR run: 99 | final GE for correct key (34): 1.0)
