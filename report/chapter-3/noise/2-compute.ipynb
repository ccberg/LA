# %%
import os

import numpy as np
from tensorflow.keras.models import *

from src.dlla.berg import make_mlp
from src.dlla.hw import prepare_traces_dl, dlla_known_p
from src.dlla.wegener import make_mlp_wegener, wegener_p
from src.tools.la import shuffle
from src.trace_set.database import Database
from src.trace_set.pollution import Pollution, PollutionType
from src.trace_set.set_hw import TraceSetHW

# %%
from src.tvla.cri import rho_test, tvla_t_test


def store_results(database: Database, method: str, pollution: Pollution, p):
    file_name = f"results_{database.name}.csv"
    with open(file_name, 'a') as f:
        f.write(f"{method};{pollution.type.name};{pollution.parameter};{p}\n")

# %%
LIMITS = {
    Database.ascad: (None, 1000),
    Database.ascad_none: (None, 1000),
    Database.aisy: (1000, 1000),
}

PARAMS = {
    Database.ascad: {
        PollutionType.desync: np.arange(0, 2.05, .05),
        PollutionType.gauss: np.arange(0, 5.1, .1)
    },
    Database.ascad_none: {
        PollutionType.desync: np.arange(0, 205, 5),
        PollutionType.gauss: np.arange(0, 102, 2)
    },
    Database.aisy: {
        PollutionType.desync: np.arange(0, 460, 10),
        PollutionType.gauss: np.arange(0, 4100, 100)
    }
}

def get_params(db: Database, pollution_type: PollutionType):
    return PARAMS[db][pollution_type]

def get_limit(db: Database):
    return LIMITS[db]

def get_order(db: Database):
    if db is Database.ascad:
        return 2

    return 3

def la_benchmark(db: Database, pollution_type: PollutionType, params):
    for param in params:
        pollution = Pollution(pollution_type, param)
        print("Load traces         ", end="\r")
        prof_lim, att_lim = get_limit(db)
        trace_set = TraceSetHW(db, pollution, (prof_lim, att_lim))

        if os.path.exists(trace_set.path):
            # print("Prepare traces (1/3)", end="\r")
            # x9, y9, x9_att, y9_att = prepare_traces_dl(*trace_set.profile(), *trace_set.attack())
            # print("Prepare traces (3/3)", end="\r")
            # x2b, y2b, x2b_att, y2b_att = prepare_traces_dl(*trace_set.profile_la(), *trace_set.attack_la(True), num_classes=2)
            #
            # print("Make model (1/3)    ", end="\r")
            # mdl_open = make_mlp(x9, y9, progress=False)
            # print("Make model (3/3)    ", end="\r")
            # mdl_wegener = make_mlp_wegener(x2b, y2b, False)

            tvla_x, tvla_y = shuffle(*trace_set.profile_la())
            print("TVLA                ", end="\r")
            # tvla_ps = np.min(tvla_t_test(tvla_x[:att_lim], tvla_y[:att_lim], get_order(db), progress=False), axis=1)
            rho_p = np.min(rho_test(tvla_x[:att_lim], tvla_y[:att_lim], progress=False), axis=1)[0]

            # print("Predict             ", end="\r")
            # dlla_k_p = dlla_known_p(mdl_open, x9_att, y9_att)
            # dlla_wegener_p = wegener_p(mdl_wegener, x2b_att, y2b_att)

            title = f"{pollution_type} ({param})."
            print(f"{title} TVLA rho ({rho_p}).")
            # print(f"{title} TVLA t ({tvla_ps}). TVLA rho ({rho_p}). DLLA known key ({dlla_k_p}). DLLA Wegener ({dlla_wegener_p})")

            # for order, p in enumerate(tvla_ps):
            #     if order > 0:
            #         store_results(db, f"tvla_t_{order}", pollution, p)

            store_results(db, "tvla_rho", pollution, rho_p)
            # store_results(db, "dlla_open", pollution, dlla_k_p)
            # store_results(db, "dlla_wegener", pollution, dlla_wegener_p)

        # print()

la_benchmark(Database.ascad_none, PollutionType.desync, [0])
# Out:
# PollutionType.desync (0). TVLA rho (5.736683290610134e-134).

# %%
def la_benchmark_all(db: Database):
    for poll in [PollutionType.desync, PollutionType.gauss]:
        la_benchmark(db, poll, get_params(db, poll))

while True:
    la_benchmark_all(Database.aisy)
    la_benchmark_all(Database.ascad)
    la_benchmark_all(Database.ascad_none)
# Out:
# PollutionType.desync (0). TVLA rho (8.504552810546213e-12).
# PollutionType.desync (10). TVLA rho (7.838330881175729e-11).
# PollutionType.desync (20). TVLA rho (1.0356954702000692e-11).
# PollutionType.desync (30). TVLA rho (4.39427337024717e-11).
# PollutionType.desync (40). TVLA rho (5.431272827399694e-10).
# PollutionType.desync (50). TVLA rho (2.3946726204923293e-09).
# PollutionType.desync (60). TVLA rho (5.361511092970994e-09).
# PollutionType.desync (70). TVLA rho (1.7829890790463252e-10).
# PollutionType.desync (80). TVLA rho (6.015952887426258e-10).
# PollutionType.desync (90). TVLA rho (6.165592455581402e-10).
# PollutionType.desync (100). TVLA rho (1.5861543079181358e-08).
# PollutionType.desync (110). TVLA rho (1.3933942108271882e-07).
# PollutionType.desync (120). TVLA rho (3.4799560062900175e-09).
# PollutionType.desync (130). TVLA rho (1.2608384094065531e-06).
# PollutionType.desync (140). TVLA rho (3.441671144352356e-08).
# PollutionType.desync (150). TVLA rho (9.813917862171963e-08).
# PollutionType.desync (160). TVLA rho (2.77720859974948e-08).
# PollutionType.desync (170). TVLA rho (2.833179872110334e-07).
# PollutionType.desync (180). TVLA rho (2.2575934203568073e-07).
# PollutionType.desync (190). TVLA rho (3.48160888926571e-07).
# PollutionType.desync (200). TVLA rho (3.4093757433482653e-06).
# PollutionType.desync (210). TVLA rho (6.877790529694348e-06).
# PollutionType.desync (220). TVLA rho (2.0375953109359975e-07).
# PollutionType.desync (230). TVLA rho (1.9455850454804655e-05).
# PollutionType.desync (240). TVLA rho (7.974622055855132e-07).
# PollutionType.desync (250). TVLA rho (3.1943567792629024e-05).
# PollutionType.desync (260). TVLA rho (7.677253498879853e-07).
# PollutionType.desync (270). TVLA rho (0.00010489663519094859).
# PollutionType.desync (280). TVLA rho (0.00013711447918139853).
# PollutionType.desync (290). TVLA rho (6.966142140586985e-06).
# PollutionType.desync (300). TVLA rho (5.4315726796692034e-05).
# PollutionType.desync (310). TVLA rho (9.931174716818878e-05).
# PollutionType.desync (320). TVLA rho (2.2127583118673776e-05).
# PollutionType.desync (330). TVLA rho (0.00022030733722840302).
# PollutionType.desync (340). TVLA rho (3.850029535435305e-06).
# PollutionType.desync (350). TVLA rho (0.00028515194385334247).
# PollutionType.desync (360). TVLA rho (6.953436921310246e-05).
# PollutionType.desync (370). TVLA rho (0.0001389710775984323).
# PollutionType.desync (380). TVLA rho (0.000263477253412425).
# PollutionType.desync (390). TVLA rho (2.47899673021653e-06).
# PollutionType.desync (400). TVLA rho (0.0001174717836300253).
# PollutionType.desync (410). TVLA rho (0.0004899915291611905).
# PollutionType.desync (420). TVLA rho (0.0015849297912084053).
# PollutionType.desync (430). TVLA rho (0.0037073134264269145).
# PollutionType.desync (440). TVLA rho (0.00015725134581434237).
# PollutionType.desync (450). TVLA rho (0.0029781506195549964).
# PollutionType.gauss (0). TVLA rho (6.7320264806524676e-12).
# PollutionType.gauss (100). TVLA rho (2.202588312726001e-09).
# PollutionType.gauss (200). TVLA rho (2.0732215806479284e-06).
# PollutionType.gauss (300). TVLA rho (2.4558763746444554e-05).
# PollutionType.gauss (400). TVLA rho (0.00037446563180779715).
# PollutionType.gauss (500). TVLA rho (0.002579258243507667).
# PollutionType.gauss (600). TVLA rho (0.002910099747730254).
# PollutionType.gauss (700). TVLA rho (0.003525706471343445).
# PollutionType.gauss (800). TVLA rho (0.004093914539024248).
# PollutionType.gauss (900). TVLA rho (0.016267165121652324).
# PollutionType.gauss (1000). TVLA rho (0.010197475031942418).
# PollutionType.gauss (1100). TVLA rho (0.003773047617959316).
# PollutionType.gauss (1200). TVLA rho (0.0071323051225609556).
# PollutionType.gauss (1300). TVLA rho (0.014700408946199117).
# PollutionType.gauss (1400). TVLA rho (0.04562679085651033).
# PollutionType.gauss (1500). TVLA rho (0.018915495374561647).
# PollutionType.gauss (1600). TVLA rho (0.019947859508370042).
# PollutionType.gauss (1700). TVLA rho (0.024012745419953765).
# PollutionType.gauss (1800). TVLA rho (0.005469798547598621).
# PollutionType.gauss (1900). TVLA rho (0.013226337449954469).
# PollutionType.gauss (2000). TVLA rho (0.020527993048683385).
# PollutionType.gauss (2100). TVLA rho (0.015928052588331968).
# PollutionType.gauss (2200). TVLA rho (0.003889390546892202).
# PollutionType.gauss (2300). TVLA rho (0.018361209272356304).
# PollutionType.gauss (2400). TVLA rho (0.005880876391085677).
# PollutionType.gauss (2500). TVLA rho (0.028108581151804826).
# PollutionType.gauss (2600). TVLA rho (0.03094013617860017).
# PollutionType.gauss (2700). TVLA rho (0.031983264780612815).
# PollutionType.gauss (2800). TVLA rho (0.028646156597694813).
# PollutionType.gauss (2900). TVLA rho (0.0035863094693394403).
# PollutionType.gauss (3000). TVLA rho (0.03171811809860987).
# PollutionType.gauss (3100). TVLA rho (0.018983388086153734).
# PollutionType.gauss (3200). TVLA rho (0.011884930702171715).
# PollutionType.gauss (3300). TVLA rho (0.01469506057248665).
# PollutionType.gauss (3400). TVLA rho (0.014881919781868815).
# PollutionType.gauss (3500). TVLA rho (0.040486528556174996).
# PollutionType.gauss (3600). TVLA rho (0.012857213526175531).
# PollutionType.gauss (3700). TVLA rho (0.010091065681055106).
# PollutionType.gauss (3800). TVLA rho (0.009621321186900966).
# PollutionType.gauss (3900). TVLA rho (0.018691064233465546).
# PollutionType.gauss (4000). TVLA rho (0.01965331119734902).
# PollutionType.desync (0.0). TVLA rho (0.07888437191579335).
# PollutionType.desync (0.05). TVLA rho (0.014373044609009436).
# PollutionType.desync (0.1). TVLA rho (0.03078569477084091).
# PollutionType.desync (0.15000000000000002). TVLA rho (0.053463585490260576).
# PollutionType.desync (0.2). TVLA rho (0.01896225961484478).
# PollutionType.desync (0.25). TVLA rho (0.04365952139914469).
# PollutionType.desync (0.30000000000000004). TVLA rho (0.05186060790284308).
# PollutionType.desync (0.35000000000000003). TVLA rho (0.06740268863227068).
# PollutionType.desync (0.4). TVLA rho (0.04931801904643183).
# PollutionType.desync (0.45). TVLA rho (0.024469328513983462).
# PollutionType.desync (0.5). TVLA rho (0.00481040668050255).
# PollutionType.desync (0.55). TVLA rho (0.023046578963237207).
# PollutionType.desync (0.6000000000000001). TVLA rho (0.0059732654189727785).
# PollutionType.desync (0.65). TVLA rho (0.11496122792393194).
# PollutionType.desync (0.7000000000000001). TVLA rho (0.08385304112429909).
# PollutionType.desync (0.75). TVLA rho (0.05043240826060486).
# PollutionType.desync (0.8). TVLA rho (0.0450264483895452).
# PollutionType.desync (0.8500000000000001). TVLA rho (0.0186876143092736).
# PollutionType.desync (0.9). TVLA rho (0.047425236189712054).
# PollutionType.desync (0.9500000000000001). TVLA rho (0.07142725645261759).
# PollutionType.desync (1.0). TVLA rho (0.11542891684068005).
# PollutionType.desync (1.05). TVLA rho (0.035476828609733994).
# PollutionType.desync (1.1). TVLA rho (0.08656354618016696).
# PollutionType.desync (1.1500000000000001). TVLA rho (0.03858738198611765).
# PollutionType.desync (1.2000000000000002). TVLA rho (0.009275278452948529).
# PollutionType.desync (1.25). TVLA rho (0.02186432088543661).
# PollutionType.desync (1.3). TVLA rho (0.03769944758789929).
# PollutionType.desync (1.35). TVLA rho (0.06445368643086226).
# PollutionType.desync (1.4000000000000001). TVLA rho (0.03816006618795182).
# PollutionType.desync (1.4500000000000002). TVLA rho (0.12017367761361754).
# PollutionType.desync (1.5). TVLA rho (0.026343178584216295).
# PollutionType.desync (1.55). TVLA rho (0.09834185845454638).
# PollutionType.desync (1.6). TVLA rho (0.12841037521308768).
# PollutionType.desync (1.6500000000000001). TVLA rho (0.01117960595230322).
# PollutionType.desync (1.7000000000000002). TVLA rho (0.0329105971333588).
# PollutionType.desync (1.75). TVLA rho (0.024401161412013993).
# PollutionType.desync (1.8). TVLA rho (0.02167155900496721).
# PollutionType.desync (1.85). TVLA rho (0.04281672702323957).
# PollutionType.desync (1.9000000000000001). TVLA rho (0.024501340876972234).
# PollutionType.desync (1.9500000000000002). TVLA rho (0.01855719045436795).
# PollutionType.desync (2.0). TVLA rho (0.1115428658695849).
# PollutionType.gauss (0.0). TVLA rho (0.01917412838473102).
# PollutionType.gauss (0.1). TVLA rho (0.023950425341044336).
# PollutionType.gauss (0.2). TVLA rho (0.015661069127750966).
# PollutionType.gauss (0.30000000000000004). TVLA rho (0.04359625599062841).
# PollutionType.gauss (0.4). TVLA rho (0.03190824966328771).
# PollutionType.gauss (0.5). TVLA rho (0.02778243290286).
# PollutionType.gauss (0.6000000000000001). TVLA rho (0.013829744849106988).
# PollutionType.gauss (0.7000000000000001). TVLA rho (0.011041677950638094).
# PollutionType.gauss (0.8). TVLA rho (0.03369730082735223).
# PollutionType.gauss (0.9). TVLA rho (0.03222683822528822).
# PollutionType.gauss (1.0). TVLA rho (0.0420836242028784).
# PollutionType.gauss (1.1). TVLA rho (0.025236563325377118).
# PollutionType.gauss (1.2000000000000002). TVLA rho (0.04010602483799481).
# PollutionType.gauss (1.3). TVLA rho (0.06018338093672514).
# PollutionType.gauss (1.4000000000000001). TVLA rho (0.00512437320081259).
# PollutionType.gauss (1.5). TVLA rho (0.009956325389795196).
# PollutionType.gauss (1.6). TVLA rho (0.025477442858344183).
# PollutionType.gauss (1.7000000000000002). TVLA rho (0.005026896605643586).
# PollutionType.gauss (1.8). TVLA rho (0.03406880855052013).
# PollutionType.gauss (1.9000000000000001). TVLA rho (0.027451735987203314).
# PollutionType.gauss (2.0). TVLA rho (0.009925592477506552).
# PollutionType.gauss (2.1). TVLA rho (0.00859717526442441).
# PollutionType.gauss (2.2). TVLA rho (0.013786897266041338).
# PollutionType.gauss (2.3000000000000003). TVLA rho (0.04407826886612187).
# PollutionType.gauss (2.4000000000000004). TVLA rho (0.016588271113095736).
# PollutionType.gauss (2.5). TVLA rho (0.01337393160243856).
# PollutionType.gauss (2.6). TVLA rho (0.036566635808108205).
# PollutionType.gauss (2.7). TVLA rho (0.00901628562404847).
# PollutionType.gauss (2.8000000000000003). TVLA rho (0.016092714070462744).
# PollutionType.gauss (2.9000000000000004). TVLA rho (0.008930891881431252).
# PollutionType.gauss (3.0). TVLA rho (0.03908644557653758).
# PollutionType.gauss (3.1). TVLA rho (0.021937929938473873).
# PollutionType.gauss (3.2). TVLA rho (0.007824611048747434).
# PollutionType.gauss (3.3000000000000003). TVLA rho (0.032285245956194024).
# PollutionType.gauss (3.4000000000000004). TVLA rho (0.010169095229751785).
# PollutionType.gauss (3.5). TVLA rho (0.004390402807799434).
# PollutionType.gauss (3.6). TVLA rho (0.018905534430833135).
# PollutionType.gauss (3.7). TVLA rho (0.034681005578266054).
# PollutionType.gauss (3.8000000000000003). TVLA rho (0.00571483945905903).
# PollutionType.gauss (3.9000000000000004). TVLA rho (0.02046738241916773).
# PollutionType.gauss (4.0). TVLA rho (0.04105841709482588).
# PollutionType.gauss (4.1000000000000005). TVLA rho (0.021386924445917575).
# PollutionType.gauss (4.2). TVLA rho (0.014332886119383501).
# PollutionType.gauss (4.3). TVLA rho (0.023449131771173127).
# PollutionType.gauss (4.4). TVLA rho (0.009535796571627047).
# PollutionType.gauss (4.5). TVLA rho (0.02802571701843367).
# PollutionType.gauss (4.6000000000000005). TVLA rho (0.023087162965389273).
# PollutionType.gauss (4.7). TVLA rho (0.014621130397332361).
# PollutionType.gauss (4.800000000000001). TVLA rho (0.02859938852420684).
# PollutionType.gauss (4.9). TVLA rho (0.018862720419134213).
# PollutionType.gauss (5.0). TVLA rho (0.002936987127233593).
# PollutionType.desync (0). TVLA rho (3.7783905376645915e-136).
# PollutionType.desync (5). TVLA rho (0.03821622628833572).
# PollutionType.desync (10). TVLA rho (0.12622129184588007).
# PollutionType.desync (15). TVLA rho (0.14296628980092538).
# PollutionType.desync (20). TVLA rho (0.1832412123549617).
# PollutionType.desync (25). TVLA rho (0.17819502202478033).
# PollutionType.desync (30). TVLA rho (0.20668852912287916).
# PollutionType.desync (35). TVLA rho (0.07583715185537222).
# PollutionType.desync (40). TVLA rho (0.053030929061297145).
# PollutionType.desync (45). TVLA rho (0.09608594438636554).
# PollutionType.desync (50). TVLA rho (0.1503968467267119).
# PollutionType.desync (55). TVLA rho (0.037061958211885744).
# PollutionType.desync (60). TVLA rho (0.1917318870450787).
# PollutionType.desync (65). TVLA rho (0.22931717672283125).
# PollutionType.desync (70). TVLA rho (0.1924891628937282).
# PollutionType.desync (75). TVLA rho (0.06504727340076519).
# PollutionType.desync (80). TVLA rho (0.0398064711884696).
# PollutionType.desync (85). TVLA rho (0.07429696819014701).
# PollutionType.desync (90). TVLA rho (0.05042904428834526).
# PollutionType.desync (95). TVLA rho (0.18396162780212755).
# PollutionType.desync (100). TVLA rho (0.1998486931075335).
# PollutionType.desync (105). TVLA rho (0.14959664637514158).
# PollutionType.desync (110). TVLA rho (0.05800826520988675).
# PollutionType.desync (115). TVLA rho (0.047169239671590445).
# PollutionType.desync (120). TVLA rho (0.2391798893017777).
# PollutionType.desync (125). TVLA rho (0.22245662590917392).
# PollutionType.desync (130). TVLA rho (0.3146151173150785).
# PollutionType.desync (135). TVLA rho (0.19993815714047802).
# PollutionType.desync (140). TVLA rho (0.1440688889519584).
# PollutionType.desync (145). TVLA rho (0.21400166373271357).
# PollutionType.desync (150). TVLA rho (0.05104651365094439).
# PollutionType.desync (155). TVLA rho (0.007295175780702536).
# PollutionType.desync (160). TVLA rho (0.03209545446417162).
# PollutionType.desync (165). TVLA rho (0.06685110582454204).
# PollutionType.desync (170). TVLA rho (0.012069623276989072).
# PollutionType.desync (175). TVLA rho (0.09233251552991316).
# PollutionType.desync (180). TVLA rho (0.0015268102742115413).
# PollutionType.desync (185). TVLA rho (0.08556226624181985).
# PollutionType.desync (190). TVLA rho (0.06326332987776359).
# PollutionType.desync (195). TVLA rho (0.14986983714917954).
# PollutionType.desync (200). TVLA rho (0.01629235535198471).
# PollutionType.gauss (0). TVLA rho (1.058422874770864e-143).
# PollutionType.gauss (2). TVLA rho (6.652826153024117e-90).
# PollutionType.gauss (4). TVLA rho (1.2996437758760334e-56).
# PollutionType.gauss (6). TVLA rho (1.2083467275396532e-37).
# PollutionType.gauss (8). TVLA rho (9.407049112212448e-33).
# PollutionType.gauss (10). TVLA rho (3.838177783532802e-26).
# PollutionType.gauss (12). TVLA rho (2.652700116357915e-17).
# PollutionType.gauss (14). TVLA rho (1.8288675276476997e-14).
# PollutionType.gauss (16). TVLA rho (9.161496837466096e-12).
# PollutionType.gauss (18). TVLA rho (8.587091640263404e-09).
# PollutionType.gauss (20). TVLA rho (4.833424558747078e-10).
# PollutionType.gauss (22). TVLA rho (1.6719822318197405e-09).
# PollutionType.gauss (24). TVLA rho (2.5880386787520314e-06).
# PollutionType.gauss (26). TVLA rho (0.00012507359977874876).
# PollutionType.gauss (28). TVLA rho (1.3717797061212789e-05).
# PollutionType.gauss (30). TVLA rho (1.4873953213187644e-05).
# PollutionType.gauss (32). TVLA rho (0.00015481663256480452).
# PollutionType.gauss (34). TVLA rho (0.0001779232922746039).
# PollutionType.gauss (36). TVLA rho (0.0015864890432994135).
# PollutionType.gauss (38). TVLA rho (0.002843348738771365).
# PollutionType.gauss (40). TVLA rho (0.004141926640117894).
# PollutionType.gauss (42). TVLA rho (0.007437949358418357).
# PollutionType.gauss (44). TVLA rho (0.00015080803765996778).
# PollutionType.gauss (46). TVLA rho (0.02912947249159968).
# PollutionType.gauss (48). TVLA rho (0.00042954672858487494).
# PollutionType.gauss (50). TVLA rho (0.00029720326827039744).
# PollutionType.gauss (52). TVLA rho (0.003864266856200775).
# PollutionType.gauss (54). TVLA rho (0.008403135125204225).
# PollutionType.gauss (56). TVLA rho (0.01229504141427749).
# PollutionType.gauss (58). TVLA rho (0.0009798676058685343).
# PollutionType.gauss (60). TVLA rho (0.0008825445884757435).
# PollutionType.gauss (62). TVLA rho (0.0008609730697702441).
# PollutionType.gauss (64). TVLA rho (0.01640944783438123).
# PollutionType.gauss (66). TVLA rho (0.015951277372107116).
# PollutionType.gauss (68). TVLA rho (0.012352845684244662).
# PollutionType.gauss (70). TVLA rho (0.016232194915303682).
# PollutionType.gauss (72). TVLA rho (0.03418894854800363).
# PollutionType.gauss (74). TVLA rho (0.03237108932041869).
# PollutionType.gauss (76). TVLA rho (0.0024832168768865507).
# PollutionType.gauss (78). TVLA rho (0.01985595203980559).
# PollutionType.gauss (80). TVLA rho (0.01264263313508677).
# PollutionType.gauss (82). TVLA rho (0.01614512842259004).
# PollutionType.gauss (84). TVLA rho (0.009252684916208323).
# PollutionType.gauss (86). TVLA rho (0.04749841996446033).
# PollutionType.gauss (88). TVLA rho (0.01983636412362216).
# PollutionType.gauss (90). TVLA rho (0.006752072697594646).
# PollutionType.gauss (92). TVLA rho (0.02049453953170086).
# PollutionType.gauss (94). TVLA rho (0.023459055363828453).
# PollutionType.gauss (96). TVLA rho (0.01741626025372933).
# PollutionType.gauss (98). TVLA rho (0.027152610781286335).
# PollutionType.gauss (100). TVLA rho (0.030544603220532436).
# PollutionType.desync (0). TVLA rho (7.354985783029178e-10).
# PollutionType.desync (10). TVLA rho (5.1085724572781424e-11).
# PollutionType.desync (20). TVLA rho (2.8184894951858778e-11).
# PollutionType.desync (30). TVLA rho (1.7709223218405241e-09).
# PollutionType.desync (40). TVLA rho (3.744208353397361e-09).
# PollutionType.desync (50). TVLA rho (3.49381772182968e-09).
# PollutionType.desync (60). TVLA rho (3.227514510648796e-08).
# PollutionType.desync (70). TVLA rho (6.269579208822076e-10).
# PollutionType.desync (80). TVLA rho (4.184644778830988e-11).
# PollutionType.desync (90). TVLA rho (2.1428473335256537e-09).
# PollutionType.desync (100). TVLA rho (8.13765551573296e-09).
# PollutionType.desync (110). TVLA rho (5.381724110748993e-08).
# PollutionType.desync (120). TVLA rho (7.797895112073635e-09).
# PollutionType.desync (130). TVLA rho (3.9038241813087476e-07).
# PollutionType.desync (140). TVLA rho (2.3376665592206918e-07).
# PollutionType.desync (150). TVLA rho (7.478590485417326e-08).
# PollutionType.desync (160). TVLA rho (4.7093067312252014e-08).
# PollutionType.desync (170). TVLA rho (3.0885345898708224e-07).
# PollutionType.desync (180). TVLA rho (6.294254148220609e-07).
# PollutionType.desync (190). TVLA rho (2.96864644871637e-07).
# PollutionType.desync (200). TVLA rho (1.5020646633405818e-06).
# PollutionType.desync (210). TVLA rho (4.3476959990147297e-07).
# PollutionType.desync (220). TVLA rho (2.258501658635934e-06).
# PollutionType.desync (230). TVLA rho (4.974273950727133e-06).
# PollutionType.desync (240). TVLA rho (1.0497279787800432e-06).
# PollutionType.desync (250). TVLA rho (4.0171469724844865e-06).
# PollutionType.desync (260). TVLA rho (9.234369757278818e-05).
# PollutionType.desync (270). TVLA rho (5.219853148777495e-05).
# PollutionType.desync (280). TVLA rho (0.0001457910905507492).
# PollutionType.desync (290). TVLA rho (2.829140395989571e-07).
# PollutionType.desync (300). TVLA rho (0.0003401281993312514).
# PollutionType.desync (310). TVLA rho (0.00010849045920560461).
# PollutionType.desync (320). TVLA rho (7.054273309760189e-05).
# PollutionType.desync (330). TVLA rho (8.668713830501774e-06).
# PollutionType.desync (340). TVLA rho (8.266876035570608e-05).
# PollutionType.desync (350). TVLA rho (0.000259886789840492).
# PollutionType.desync (360). TVLA rho (3.4679773640403054e-06).
# PollutionType.desync (370). TVLA rho (0.00015188041166939962).
# PollutionType.desync (380). TVLA rho (0.00033099079295355885).
# PollutionType.desync (390). TVLA rho (2.428060860828882e-05).
# PollutionType.desync (400). TVLA rho (2.23852907359934e-05).
# PollutionType.desync (410). TVLA rho (0.002811571703442051).
# PollutionType.desync (420). TVLA rho (0.0005019027420027592).
# PollutionType.desync (430). TVLA rho (0.012462609461740793).
# PollutionType.desync (440). TVLA rho (0.0001669665381163055).
# PollutionType.desync (450). TVLA rho (0.04260840113170018).
# PollutionType.gauss (0). TVLA rho (5.266988709837096e-09).
# PollutionType.gauss (100). TVLA rho (2.835619726819805e-09).
# PollutionType.gauss (200). TVLA rho (5.734514980850096e-06).
# PollutionType.gauss (300). TVLA rho (1.0033871914421709e-05).
# PollutionType.gauss (400). TVLA rho (0.00013185475466579748).
# PollutionType.gauss (500). TVLA rho (0.0011379074646037351).
# PollutionType.gauss (600). TVLA rho (0.002468969373472692).
# PollutionType.gauss (700). TVLA rho (0.005151447870012687).
# PollutionType.gauss (800). TVLA rho (0.00011629960785112415).
# PollutionType.gauss (900). TVLA rho (0.018566774031579244).
# PollutionType.gauss (1000). TVLA rho (0.011675807460218237).
# PollutionType.gauss (1100). TVLA rho (0.004575039842319619).
# PollutionType.gauss (1200). TVLA rho (0.01659229535334743).
# PollutionType.gauss (1300). TVLA rho (0.012371580112046912).
# PollutionType.gauss (1400). TVLA rho (0.006042782445830561).
# PollutionType.gauss (1500). TVLA rho (0.042272324234444277).
# PollutionType.gauss (1600). TVLA rho (0.02972493263058167).
# PollutionType.gauss (1700). TVLA rho (0.012502564675336093).
# PollutionType.gauss (1800). TVLA rho (0.014438363433246277).
# PollutionType.gauss (1900). TVLA rho (0.029693222127263816).
# PollutionType.gauss (2000). TVLA rho (0.015242541670560708).
# PollutionType.gauss (2100). TVLA rho (0.008394451780863909).
# PollutionType.gauss (2200). TVLA rho (0.009284320873900319).
# PollutionType.gauss (2300). TVLA rho (0.010917873216083115).
# PollutionType.gauss (2400). TVLA rho (0.020605136890747913).
# PollutionType.gauss (2500). TVLA rho (0.04085714894081531).
# PollutionType.gauss (2600). TVLA rho (0.01669273175559327).
# PollutionType.gauss (2700). TVLA rho (0.007802741799770388).
# PollutionType.gauss (2800). TVLA rho (0.033854302667621836).
# PollutionType.gauss (2900). TVLA rho (0.006517300221234299).
# PollutionType.gauss (3000). TVLA rho (0.01691242010965777).
# PollutionType.gauss (3100). TVLA rho (0.015307252442041182).
# PollutionType.gauss (3200). TVLA rho (0.03379847881462477).
# PollutionType.gauss (3300). TVLA rho (0.03364926383178928).
# PollutionType.gauss (3400). TVLA rho (0.023491638258655478).
# PollutionType.gauss (3500). TVLA rho (0.03048036835791707).
# PollutionType.gauss (3600). TVLA rho (0.03227183676422062).
# PollutionType.gauss (3700). TVLA rho (0.007909879285735074).
# PollutionType.gauss (3800). TVLA rho (0.00934067110433858).
# PollutionType.gauss (3900). TVLA rho (0.01711302837347).
# PollutionType.gauss (4000). TVLA rho (0.020226164833374843).
# PollutionType.desync (0.0). TVLA rho (0.013837128916438514).
# PollutionType.desync (0.05). TVLA rho (0.05346357137190685).
# PollutionType.desync (0.1). TVLA rho (0.037718300725814634).
# PollutionType.desync (0.15000000000000002). TVLA rho (0.0071199326818573655).
# PollutionType.desync (0.2). TVLA rho (0.01281174510153928).
# PollutionType.desync (0.25). TVLA rho (0.038427388433072696).
# PollutionType.desync (0.30000000000000004). TVLA rho (0.06421427679976947).
# PollutionType.desync (0.35000000000000003). TVLA rho (0.028240531906613305).
# PollutionType.desync (0.4). TVLA rho (0.10248652800189954).
# PollutionType.desync (0.45). TVLA rho (0.01847424571971198).
# PollutionType.desync (0.5). TVLA rho (0.0191995328411105).
# PollutionType.desync (0.55). TVLA rho (0.02605296725278057).
# PollutionType.desync (0.6000000000000001). TVLA rho (0.021445166481781422).
# PollutionType.desync (0.65). TVLA rho (0.09951130323033514).
# PollutionType.desync (0.7000000000000001). TVLA rho (0.025063169944617367).
# PollutionType.desync (0.75). TVLA rho (0.10821559052022808).
# PollutionType.desync (0.8). TVLA rho (0.07935137522899967).
# PollutionType.desync (0.8500000000000001). TVLA rho (0.035339967833713216).
# PollutionType.desync (0.9). TVLA rho (0.042356105722514).
# PollutionType.desync (0.9500000000000001). TVLA rho (0.04519438593438681).
# PollutionType.desync (1.0). TVLA rho (0.016850854970284518).
# PollutionType.desync (1.05). TVLA rho (0.060981110897444034).
# PollutionType.desync (1.1). TVLA rho (0.03998394531182704).
# PollutionType.desync (1.1500000000000001). TVLA rho (0.06528546825539909).
# PollutionType.desync (1.2000000000000002). TVLA rho (0.09497493724834649).
# PollutionType.desync (1.25). TVLA rho (0.06854773725660915).
# PollutionType.desync (1.3). TVLA rho (0.09792988567253973).
# PollutionType.desync (1.35). TVLA rho (0.020151361731110016).
# PollutionType.desync (1.4000000000000001). TVLA rho (0.11032832010246517).
# PollutionType.desync (1.4500000000000002). TVLA rho (0.04839787011385545).
# PollutionType.desync (1.5). TVLA rho (0.0986142459514405).
# PollutionType.desync (1.55). TVLA rho (0.09606561348836669).
# PollutionType.desync (1.6). TVLA rho (0.040368005396176646).
# PollutionType.desync (1.6500000000000001). TVLA rho (0.08566773698057177).
# PollutionType.desync (1.7000000000000002). TVLA rho (0.156467771793191).
# PollutionType.desync (1.75). TVLA rho (0.0840217510412996).
# PollutionType.desync (1.8). TVLA rho (0.06829307237073592).
# PollutionType.desync (1.85). TVLA rho (0.0321728860406409).
# PollutionType.desync (1.9000000000000001). TVLA rho (0.10325307193795916).
# PollutionType.desync (1.9500000000000002). TVLA rho (0.02930361324654134).
# PollutionType.desync (2.0). TVLA rho (0.010987944719630756).
# PollutionType.gauss (0.0). TVLA rho (0.038531877288335965).
# PollutionType.gauss (0.1). TVLA rho (0.03785473355293209).
# PollutionType.gauss (0.2). TVLA rho (0.07723792412706487).
# PollutionType.gauss (0.30000000000000004). TVLA rho (0.010845088743645733).
# PollutionType.gauss (0.4). TVLA rho (0.01775001617879776).
# PollutionType.gauss (0.5). TVLA rho (0.07825628493227274).
# PollutionType.gauss (0.6000000000000001). TVLA rho (0.021506521413133632).
# PollutionType.gauss (0.7000000000000001). TVLA rho (0.010733579597706952).
# PollutionType.gauss (0.8). TVLA rho (0.007420615123227974).
# PollutionType.gauss (0.9). TVLA rho (0.023744887755040488).
# PollutionType.gauss (1.0). TVLA rho (0.014617197015740727).
# PollutionType.gauss (1.1). TVLA rho (0.011779736259131415).
# PollutionType.gauss (1.2000000000000002). TVLA rho (0.028921588627067018).
# PollutionType.gauss (1.3). TVLA rho (0.041108460936054275).
# PollutionType.gauss (1.4000000000000001). TVLA rho (0.009461379377025764).
# PollutionType.gauss (1.5). TVLA rho (0.008087558546307237).
# PollutionType.gauss (1.6). TVLA rho (0.0036099205368209254).
# PollutionType.gauss (1.7000000000000002). TVLA rho (0.018006157124823976).
# PollutionType.gauss (1.8). TVLA rho (0.027361972503958304).
# PollutionType.gauss (1.9000000000000001). TVLA rho (0.022566927527032654).
# PollutionType.gauss (2.0). TVLA rho (0.024591673634781146).
# PollutionType.gauss (2.1). TVLA rho (0.025988546555127282).
# PollutionType.gauss (2.2). TVLA rho (0.017483905234474247).
# PollutionType.gauss (2.3000000000000003). TVLA rho (0.05735678804485619).
# PollutionType.gauss (2.4000000000000004). TVLA rho (0.036620864092392666).
# PollutionType.gauss (2.5). TVLA rho (0.010879670888777471).
# PollutionType.gauss (2.6). TVLA rho (0.029220707670722157).
# PollutionType.gauss (2.7). TVLA rho (0.04181548706888023).
# PollutionType.gauss (2.8000000000000003). TVLA rho (0.040416109888531226).
# PollutionType.gauss (2.9000000000000004). TVLA rho (0.028848776139257817).
# PollutionType.gauss (3.0). TVLA rho (0.03458288727571398).
# PollutionType.gauss (3.1). TVLA rho (0.0013631764900363579).
# PollutionType.gauss (3.2). TVLA rho (0.017146202770603785).
# PollutionType.gauss (3.3000000000000003). TVLA rho (0.018402599676687826).
# PollutionType.gauss (3.4000000000000004). TVLA rho (0.02203737268365776).
# PollutionType.gauss (3.5). TVLA rho (0.021334543277351615).
# PollutionType.gauss (3.6). TVLA rho (0.013208004516889405).
# PollutionType.gauss (3.7). TVLA rho (0.022963506421306488).
# PollutionType.gauss (3.8000000000000003). TVLA rho (0.017543290751237853).
# PollutionType.gauss (3.9000000000000004). TVLA rho (0.024940205785030894).
# PollutionType.gauss (4.0). TVLA rho (0.01964150865516283).
# PollutionType.gauss (4.1000000000000005). TVLA rho (0.013103990865658327).
# PollutionType.gauss (4.2). TVLA rho (0.008807620347930964).
# PollutionType.gauss (4.3). TVLA rho (0.021334815969121106).
# PollutionType.gauss (4.4). TVLA rho (0.04790129629898245).
# PollutionType.gauss (4.5). TVLA rho (0.02299902227106112).
# PollutionType.gauss (4.6000000000000005). TVLA rho (0.01938512460396328).
# PollutionType.gauss (4.7). TVLA rho (0.027501693390732617).
# PollutionType.gauss (4.800000000000001). TVLA rho (0.02411621007619721).
# PollutionType.gauss (4.9). TVLA rho (0.026166944229928196).
# PollutionType.gauss (5.0). TVLA rho (0.03126688516491093).
# PollutionType.desync (0). TVLA rho (2.1303089744415405e-137).
# PollutionType.desync (5). TVLA rho (0.00047173684441547407).
# PollutionType.desync (10). TVLA rho (0.10420301595545906).
# PollutionType.desync (15). TVLA rho (0.0524742075237171).
# PollutionType.desync (20). TVLA rho (0.08736143074938577).
# PollutionType.desync (25). TVLA rho (0.09970100170885915).
# PollutionType.desync (30). TVLA rho (0.05302100194661558).
# PollutionType.desync (35). TVLA rho (0.07867740216075354).
# PollutionType.desync (40). TVLA rho (0.13257790531427077).
# PollutionType.desync (45). TVLA rho (0.04980230491397755).
# PollutionType.desync (50). TVLA rho (0.011078455257807852).
# PollutionType.desync (55). TVLA rho (0.23275279183055975).
# PollutionType.desync (60). TVLA rho (0.07532786173733594).
# PollutionType.desync (65). TVLA rho (0.2367650056409789).
# PollutionType.desync (70). TVLA rho (0.12870882228441535).
# PollutionType.desync (75). TVLA rho (0.07796007040118104).
# PollutionType.desync (80). TVLA rho (0.048555049455411455).
# PollutionType.desync (85). TVLA rho (0.09326481799124599).
# PollutionType.desync (90). TVLA rho (0.25370104090875334).
# PollutionType.desync (95). TVLA rho (0.13770836334918873).
# PollutionType.desync (100). TVLA rho (0.05490340092070318).
# PollutionType.desync (105). TVLA rho (0.03308277238743032).
# PollutionType.desync (110). TVLA rho (0.06723507187135598).
# PollutionType.desync (115). TVLA rho (0.07872051184154144).
# PollutionType.desync (120). TVLA rho (0.03475322019177353).
# PollutionType.desync (125). TVLA rho (0.09110180040166918).
# PollutionType.desync (130). TVLA rho (0.032091603059661925).
# PollutionType.desync (135). TVLA rho (0.26191347291201716).
# PollutionType.desync (140). TVLA rho (0.14217298548808355).
# PollutionType.desync (145). TVLA rho (0.03999460504025495).
# PollutionType.desync (150). TVLA rho (0.11785127735985926).
# PollutionType.desync (155). TVLA rho (0.04716998770503648).
# PollutionType.desync (160). TVLA rho (0.02073128193358687).
# PollutionType.desync (165). TVLA rho (0.06369973428330025).
# PollutionType.desync (170). TVLA rho (0.06945050901370918).
# PollutionType.desync (175). TVLA rho (0.0146861276513494).
# PollutionType.desync (180). TVLA rho (0.07898240010389826).
# PollutionType.desync (185). TVLA rho (0.0943173126034273).
# PollutionType.desync (190). TVLA rho (0.039467923302690146).
# PollutionType.desync (195). TVLA rho (0.06307008138521666).
# PollutionType.desync (200). TVLA rho (0.02817612264969639).
# PollutionType.gauss (0). TVLA rho (4.631497897024854e-131).
# PollutionType.gauss (2). TVLA rho (6.247239786878159e-91).
# PollutionType.gauss (4). TVLA rho (1.0142094519989047e-58).
# PollutionType.gauss (6). TVLA rho (4.6251140477396576e-39).
# PollutionType.gauss (8). TVLA rho (9.277342582613381e-35).
# PollutionType.gauss (10). TVLA rho (3.135838307748783e-22).
# PollutionType.gauss (12). TVLA rho (4.996967133892094e-18).
# PollutionType.gauss (14). TVLA rho (2.823572580233844e-20).
# PollutionType.gauss (16). TVLA rho (8.736856573204582e-09).
# PollutionType.gauss (18). TVLA rho (2.894688884153553e-12).
# PollutionType.gauss (20). TVLA rho (1.4224475722677833e-07).
# PollutionType.gauss (22). TVLA rho (6.109114708351109e-08).
# PollutionType.gauss (24). TVLA rho (8.63930616533457e-07).
# PollutionType.gauss (26). TVLA rho (2.9754344788198074e-05).
# PollutionType.gauss (28). TVLA rho (8.131932733892338e-05).
# PollutionType.gauss (30). TVLA rho (7.004390865128752e-05).
# PollutionType.gauss (32). TVLA rho (2.608052645606286e-07).
# PollutionType.gauss (34). TVLA rho (0.000189896954975831).
# PollutionType.gauss (36). TVLA rho (0.0010428534284140007).
# PollutionType.gauss (38). TVLA rho (0.0009999217820958817).
# PollutionType.gauss (40). TVLA rho (0.003235646828688439).
# PollutionType.gauss (42). TVLA rho (0.004772259056623246).
# PollutionType.gauss (44). TVLA rho (0.0027952743006307273).
# PollutionType.gauss (46). TVLA rho (0.0025892940502100065).
# PollutionType.gauss (48). TVLA rho (0.0004977739211900358).
# PollutionType.gauss (50). TVLA rho (0.005066940802909336).
# PollutionType.gauss (52). TVLA rho (0.018321336520229516).
# PollutionType.gauss (54). TVLA rho (0.000543265518344165).
# PollutionType.gauss (56). TVLA rho (0.014527100607552912).
# PollutionType.gauss (58). TVLA rho (0.02000638827300204).
# PollutionType.gauss (60). TVLA rho (0.022513171104095554).
# PollutionType.gauss (62). TVLA rho (0.011255198000735525).
# PollutionType.gauss (64). TVLA rho (0.017972522810782498).
# PollutionType.gauss (66). TVLA rho (0.008019144221541579).
# PollutionType.gauss (68). TVLA rho (0.007657559022933443).
# PollutionType.gauss (70). TVLA rho (0.02746186295171448).
# PollutionType.gauss (72). TVLA rho (0.006952012751511451).
# PollutionType.gauss (74). TVLA rho (0.01726965493396508).
# PollutionType.gauss (76). TVLA rho (0.01495237384221374).
# PollutionType.gauss (78). TVLA rho (0.006761193322326706).
# PollutionType.gauss (80). TVLA rho (0.030146613305823765).
# PollutionType.gauss (82). TVLA rho (0.014181830107938189).
# PollutionType.gauss (84). TVLA rho (0.019773484739613375).
# PollutionType.gauss (86). TVLA rho (0.02456760063027282).
# PollutionType.gauss (88). TVLA rho (0.004168552932600521).
# PollutionType.gauss (90). TVLA rho (0.020688636885880737).
# PollutionType.gauss (92). TVLA rho (0.026672730179255404).
# PollutionType.gauss (94). TVLA rho (0.056342262074214396).
# PollutionType.gauss (96). TVLA rho (0.0034843153364507245).
# PollutionType.gauss (98). TVLA rho (0.006202587167716136).
# PollutionType.gauss (100). TVLA rho (0.022525605508507518).
# PollutionType.desync (0). TVLA rho (7.034661772102664e-11).
# PollutionType.desync (10). TVLA rho (1.666370154941374e-11).
# PollutionType.desync (20). TVLA rho (8.467313716400353e-09).
# PollutionType.desync (30). TVLA rho (6.758274092324852e-11).
# PollutionType.desync (40). TVLA rho (7.508172888068404e-10).
# PollutionType.desync (50). TVLA rho (3.5334223429207136e-09).
# PollutionType.desync (60). TVLA rho (6.182981515196549e-09).
# PollutionType.desync (70). TVLA rho (5.549168720035682e-10).
# PollutionType.desync (80). TVLA rho (6.251491987072124e-11).
# PollutionType.desync (90). TVLA rho (1.1970152409175962e-10).
# PollutionType.desync (100). TVLA rho (3.568271652172795e-08).
# PollutionType.desync (110). TVLA rho (1.2415922528339943e-08).
# PollutionType.desync (120). TVLA rho (2.838808391477808e-09).
# PollutionType.desync (130). TVLA rho (1.689438733914707e-06).
# PollutionType.desync (140). TVLA rho (4.405778957037242e-07).
# PollutionType.desync (150). TVLA rho (3.3065148094081177e-06).
# PollutionType.desync (160). TVLA rho (5.107409734819296e-07).
# PollutionType.desync (170). TVLA rho (2.1678560541058694e-08).
# PollutionType.desync (180). TVLA rho (3.2436429075221134e-07).
# PollutionType.desync (190). TVLA rho (5.751666125137145e-07).
# PollutionType.desync (200). TVLA rho (5.358689419562362e-06).
# PollutionType.desync (210). TVLA rho (1.1522186048824191e-06).
# PollutionType.desync (220). TVLA rho (5.4340799967197517e-08).
# PollutionType.desync (230). TVLA rho (5.797728875461771e-06).
# PollutionType.desync (240). TVLA rho (4.546251189048579e-06).
# PollutionType.desync (250). TVLA rho (1.2989124606420067e-05).
# PollutionType.desync (260). TVLA rho (6.601881977725869e-07).
# PollutionType.desync (270). TVLA rho (3.1613507423635435e-05).
# PollutionType.desync (280). TVLA rho (7.977236661782022e-05).
# PollutionType.desync (290). TVLA rho (2.5528920824808583e-07).
# PollutionType.desync (300). TVLA rho (6.023739978204083e-05).
# PollutionType.desync (310). TVLA rho (7.178374912704857e-05).
# PollutionType.desync (320). TVLA rho (2.151921917410243e-05).
# PollutionType.desync (330). TVLA rho (6.116361400991173e-05).
# PollutionType.desync (340). TVLA rho (5.504779365057816e-05).
# PollutionType.desync (350). TVLA rho (0.00039006180912744525).
# PollutionType.desync (360). TVLA rho (2.3158541436078447e-06).
# PollutionType.desync (370). TVLA rho (0.00020862709022960544).
# PollutionType.desync (380). TVLA rho (1.8252799178882326e-05).
# PollutionType.desync (390). TVLA rho (1.2068224062472715e-05).
# PollutionType.desync (400). TVLA rho (1.4564323527155154e-05).
# PollutionType.desync (410). TVLA rho (0.00045461540480281167).
# PollutionType.desync (420). TVLA rho (0.0006447803170076689).
# PollutionType.desync (430). TVLA rho (0.004869870641967298).
# PollutionType.desync (440). TVLA rho (0.0009153146766577644).
# PollutionType.desync (450). TVLA rho (0.0019973405887497493).
# PollutionType.gauss (0). TVLA rho (1.154520245738936e-11).
# PollutionType.gauss (100). TVLA rho (1.067656946834138e-08).
# PollutionType.gauss (200). TVLA rho (1.9920549454639838e-07).
# PollutionType.gauss (300). TVLA rho (0.00010964586838718783).
# PollutionType.gauss (400). TVLA rho (0.00024068324964864502).
# PollutionType.gauss (500). TVLA rho (0.0017209742954077873).
# PollutionType.gauss (600). TVLA rho (0.003033783714030288).
# PollutionType.gauss (700). TVLA rho (0.004078047434088554).
# PollutionType.gauss (800). TVLA rho (0.0019274384695120534).
# PollutionType.gauss (900). TVLA rho (0.013911414396787973).
# PollutionType.gauss (1000). TVLA rho (0.010874192023747611).
# PollutionType.gauss (1100). TVLA rho (0.0066989538688277785).
# PollutionType.gauss (1200). TVLA rho (0.0073842753857098).
# PollutionType.gauss (1300). TVLA rho (0.012011623875491767).
# PollutionType.gauss (1400). TVLA rho (0.010516777935725679).
# PollutionType.gauss (1500). TVLA rho (0.02967036176336798).
# PollutionType.gauss (1600). TVLA rho (0.027556701499947683).
# PollutionType.gauss (1700). TVLA rho (0.012153077473134244).
# PollutionType.gauss (1800). TVLA rho (0.015799590547938586).
# PollutionType.gauss (1900). TVLA rho (0.023125182613077024).
# PollutionType.gauss (2000). TVLA rho (0.019718670545713596).
# PollutionType.gauss (2100). TVLA rho (0.006165486748352387).
# PollutionType.gauss (2200). TVLA rho (0.00701050239571321).
# PollutionType.gauss (2300). TVLA rho (0.03500899625343128).
# PollutionType.gauss (2400). TVLA rho (0.009786938333511755).
# PollutionType.gauss (2500). TVLA rho (0.029434705181933463).
# PollutionType.gauss (2600). TVLA rho (0.012454742600070456).
# PollutionType.gauss (2700). TVLA rho (0.019408322597224248).
# PollutionType.gauss (2800). TVLA rho (0.018058469947206075).
# PollutionType.gauss (2900). TVLA rho (0.009155106172866065).
# PollutionType.gauss (3000). TVLA rho (0.031546677576782485).
# PollutionType.gauss (3100). TVLA rho (0.011438746303676738).
# PollutionType.gauss (3200). TVLA rho (0.02884166288962199).
# PollutionType.gauss (3300). TVLA rho (0.029196967321964445).
# PollutionType.gauss (3400). TVLA rho (0.011529159043332106).
# PollutionType.gauss (3500). TVLA rho (0.03366948645530244).
# PollutionType.gauss (3600). TVLA rho (0.02835208758287541).
# PollutionType.gauss (3700). TVLA rho (0.014488522781774713).
# PollutionType.gauss (3800). TVLA rho (0.007505406771023209).
# PollutionType.gauss (3900). TVLA rho (0.010421735339530938).
# PollutionType.gauss (4000). TVLA rho (0.02036100843385498).
# PollutionType.desync (0.0). TVLA rho (0.04018429811491124).
# PollutionType.desync (0.05). TVLA rho (0.02736752742985893).
# PollutionType.desync (0.1). TVLA rho (0.05690132533314644).
# PollutionType.desync (0.15000000000000002). TVLA rho (0.041212737200749874).
# PollutionType.desync (0.2). TVLA rho (0.04378692571471782).
# PollutionType.desync (0.25). TVLA rho (0.020459303223841943).
# PollutionType.desync (0.30000000000000004). TVLA rho (0.02403835931101995).
# PollutionType.desync (0.35000000000000003). TVLA rho (0.020484393799389357).
# PollutionType.desync (0.4). TVLA rho (0.030424262874188618).
# PollutionType.desync (0.45). TVLA rho (0.05927736131214152).
# PollutionType.desync (0.5). TVLA rho (0.03858863941179531).
# PollutionType.desync (0.55). TVLA rho (0.02818123730846172).
# PollutionType.desync (0.6000000000000001). TVLA rho (0.038771803477004825).
# PollutionType.desync (0.65). TVLA rho (0.0859319501647575).
# PollutionType.desync (0.7000000000000001). TVLA rho (0.05370912410317702).
# PollutionType.desync (0.75). TVLA rho (0.014793172431949575).
# PollutionType.desync (0.8). TVLA rho (0.11113817174742092).
# PollutionType.desync (0.8500000000000001). TVLA rho (0.06966296074856389).
# PollutionType.desync (0.9). TVLA rho (0.09244426339455995).
# PollutionType.desync (0.9500000000000001). TVLA rho (0.10900790196787992).
# PollutionType.desync (1.0). TVLA rho (0.042889129203806685).
# PollutionType.desync (1.05). TVLA rho (0.048362346324668966).
# PollutionType.desync (1.1). TVLA rho (0.05941315115104024).
# PollutionType.desync (1.1500000000000001). TVLA rho (0.05552659788786117).
# PollutionType.desync (1.2000000000000002). TVLA rho (0.07134995125688787).
# PollutionType.desync (1.25). TVLA rho (0.04150253376415424).
# PollutionType.desync (1.3). TVLA rho (0.041187551333294874).
# PollutionType.desync (1.35). TVLA rho (0.04715396166178199).
# PollutionType.desync (1.4000000000000001). TVLA rho (0.016764752095901135).
# PollutionType.desync (1.4500000000000002). TVLA rho (0.017496157723446464).
# PollutionType.desync (1.5). TVLA rho (0.044933266871731735).
# PollutionType.desync (1.55). TVLA rho (0.0732144865584005).
# PollutionType.desync (1.6). TVLA rho (0.09784218667317701).
# PollutionType.desync (1.6500000000000001). TVLA rho (0.013238786115100584).
# PollutionType.desync (1.7000000000000002). TVLA rho (0.05523898427454772).
# PollutionType.desync (1.75). TVLA rho (0.1438541200649027).
# PollutionType.desync (1.8). TVLA rho (0.03634000257985539).
# PollutionType.desync (1.85). TVLA rho (0.08857733739814701).
# PollutionType.desync (1.9000000000000001). TVLA rho (0.09245804011336704).
# PollutionType.desync (1.9500000000000002). TVLA rho (0.0767387877825831).
# PollutionType.desync (2.0). TVLA rho (0.02178656895910826).
# PollutionType.gauss (0.0). TVLA rho (0.07094850881763513).
# PollutionType.gauss (0.1). TVLA rho (0.029261794963281632).
# PollutionType.gauss (0.2). TVLA rho (0.06080329789949367).
# PollutionType.gauss (0.30000000000000004). TVLA rho (0.06286107501463742).
# PollutionType.gauss (0.4). TVLA rho (0.011083354328201862).
# PollutionType.gauss (0.5). TVLA rho (0.0314731099751786).
# PollutionType.gauss (0.6000000000000001). TVLA rho (0.02761138194422406).
# PollutionType.gauss (0.7000000000000001). TVLA rho (0.0488317391548368).
# PollutionType.gauss (0.8). TVLA rho (0.024611742940419793).
# PollutionType.gauss (0.9). TVLA rho (0.03557447842955308).
# PollutionType.gauss (1.0). TVLA rho (0.02331124971972863).
# PollutionType.gauss (1.1). TVLA rho (0.059210981355600725).
# PollutionType.gauss (1.2000000000000002). TVLA rho (0.006883356570279923).
# PollutionType.gauss (1.3). TVLA rho (0.023496686825051228).
# PollutionType.gauss (1.4000000000000001). TVLA rho (0.05479265077864095).
# PollutionType.gauss (1.5). TVLA rho (0.04033155859770321).
# PollutionType.gauss (1.6). TVLA rho (0.05091637517927867).
# PollutionType.gauss (1.7000000000000002). TVLA rho (0.015259687271280164).
# PollutionType.gauss (1.8). TVLA rho (0.013433749820521602).
# PollutionType.gauss (1.9000000000000001). TVLA rho (0.07505266755638686).
# PollutionType.gauss (2.0). TVLA rho (0.041309378230188834).
# PollutionType.gauss (2.1). TVLA rho (0.023933829449460636).
# PollutionType.gauss (2.2). TVLA rho (0.025662750457860456).
# PollutionType.gauss (2.3000000000000003). TVLA rho (0.02607077357695551).
# PollutionType.gauss (2.4000000000000004). TVLA rho (0.023451197166936357).
# PollutionType.gauss (2.5). TVLA rho (0.037146172758444854).
# PollutionType.gauss (2.6). TVLA rho (0.05023272713211416).
# PollutionType.gauss (2.7). TVLA rho (0.017509364614922765).
# PollutionType.gauss (2.8000000000000003). TVLA rho (0.040305805368187564).
# PollutionType.gauss (2.9000000000000004). TVLA rho (0.0060109003768970826).
# PollutionType.gauss (3.0). TVLA rho (0.042300251228350585).
# PollutionType.gauss (3.1). TVLA rho (0.021245440481459148).
# PollutionType.gauss (3.2). TVLA rho (0.01020878482321507).
# PollutionType.gauss (3.3000000000000003). TVLA rho (0.03792683894678072).
# PollutionType.gauss (3.4000000000000004). TVLA rho (0.014935488280954564).
# PollutionType.gauss (3.5). TVLA rho (0.026435603843043803).
# PollutionType.gauss (3.6). TVLA rho (0.028031913435073757).
# PollutionType.gauss (3.7). TVLA rho (0.032062524427537806).
# PollutionType.gauss (3.8000000000000003). TVLA rho (0.025139260159006242).
# PollutionType.gauss (3.9000000000000004). TVLA rho (0.06856536209759297).
# PollutionType.gauss (4.0). TVLA rho (0.03220999616601088).
# PollutionType.gauss (4.1000000000000005). TVLA rho (0.005542987947373818).
# PollutionType.gauss (4.2). TVLA rho (0.004476250936498706).
# PollutionType.gauss (4.3). TVLA rho (0.03607047395942034).
# PollutionType.gauss (4.4). TVLA rho (0.03703445259249924).
# PollutionType.gauss (4.5). TVLA rho (0.005026432925477797).
# PollutionType.gauss (4.6000000000000005). TVLA rho (0.024398937932452174).
# PollutionType.gauss (4.7). TVLA rho (0.01898066841597101).
# PollutionType.gauss (4.800000000000001). TVLA rho (0.0243311098387893).
# PollutionType.gauss (4.9). TVLA rho (0.01909581102839011).
# PollutionType.gauss (5.0). TVLA rho (0.011366253112239226).
# PollutionType.desync (0). TVLA rho (7.325296382010912e-142).
# PollutionType.desync (5). TVLA rho (0.025810026508673287).
# PollutionType.desync (10). TVLA rho (0.08831344466445591).
# PollutionType.desync (15). TVLA rho (0.12652171848714427).
# PollutionType.desync (20). TVLA rho (0.1708994338017914).
# PollutionType.desync (25). TVLA rho (0.1684327172314416).
# PollutionType.desync (30). TVLA rho (0.1618637564032821).
# PollutionType.desync (35). TVLA rho (0.3527684308489013).
# PollutionType.desync (40). TVLA rho (0.10658180585673753).
# PollutionType.desync (45). TVLA rho (0.12881258903454076).
# PollutionType.desync (50). TVLA rho (0.06599842362615378).
# PollutionType.desync (55). TVLA rho (0.09395068177421506).
# PollutionType.desync (60). TVLA rho (0.06686143077973714).
# PollutionType.desync (65). TVLA rho (0.1954212435674293).
# PollutionType.desync (70). TVLA rho (0.1313531878121642).
# PollutionType.desync (75). TVLA rho (0.2158087263394497).
# PollutionType.desync (80). TVLA rho (0.032819847996166725).
# PollutionType.desync (85). TVLA rho (0.15978637158996223).
# PollutionType.desync (90). TVLA rho (0.2242126440114074).
# PollutionType.desync (95). TVLA rho (0.16027060519767977).
# PollutionType.desync (100). TVLA rho (0.10686764207955718).
# PollutionType.desync (105). TVLA rho (0.023576892201447035).
# PollutionType.desync (110). TVLA rho (0.0792035524372377).
# PollutionType.desync (115). TVLA rho (0.10294655719465584).
# PollutionType.desync (120). TVLA rho (0.17677824269939302).
# PollutionType.desync (125). TVLA rho (0.06760905272829375).
# PollutionType.desync (130). TVLA rho (0.1780509718074217).
# PollutionType.desync (135). TVLA rho (0.17493439270357058).
# PollutionType.desync (140). TVLA rho (0.23591183996192477).
# PollutionType.desync (145). TVLA rho (0.09133685470010175).
# PollutionType.desync (150). TVLA rho (0.004724764461151988).
# PollutionType.desync (155). TVLA rho (0.2447311321044504).
# PollutionType.desync (160). TVLA rho (0.19816165717924794).
# PollutionType.desync (165). TVLA rho (0.10519928462725386).
# PollutionType.desync (170). TVLA rho (0.12370679392374462).
# PollutionType.desync (175). TVLA rho (0.1674659476848548).
# PollutionType.desync (180). TVLA rho (0.2209953681363349).
# PollutionType.desync (185). TVLA rho (0.13227630197573512).
# PollutionType.desync (190). TVLA rho (0.11924548563376569).
# PollutionType.desync (195). TVLA rho (0.17928648352690213).
# PollutionType.desync (200). TVLA rho (0.006346973542609105).
# PollutionType.gauss (0). TVLA rho (5.72705637584797e-141).
# PollutionType.gauss (2). TVLA rho (1.5138012845335391e-81).
# PollutionType.gauss (4). TVLA rho (3.739622248963379e-55).
# PollutionType.gauss (6). TVLA rho (2.8406322774130264e-40).
# PollutionType.gauss (8). TVLA rho (1.5705693977163088e-26).
# PollutionType.gauss (10). TVLA rho (3.483141938708687e-23).
# PollutionType.gauss (12). TVLA rho (4.811347534811096e-22).
# PollutionType.gauss (14). TVLA rho (1.4206669339336916e-15).
# PollutionType.gauss (16). TVLA rho (3.0053390735255726e-15).
# ...
# PollutionType.gauss (3.2). TVLA rho (0.021227671698630962).
# PollutionType.gauss (3.3000000000000003). TVLA rho (0.0035527201382053323).
# PollutionType.gauss (3.4000000000000004). TVLA rho (0.011619242952121779).
# PollutionType.gauss (3.5). TVLA rho (0.01405192277202222).
# PollutionType.gauss (3.6). TVLA rho (0.04577585505046968).
# PollutionType.gauss (3.7). TVLA rho (0.031307882085778456).
# PollutionType.gauss (3.8000000000000003). TVLA rho (0.014533871706807009).
# PollutionType.gauss (3.9000000000000004). TVLA rho (0.012710161295417546).
# PollutionType.gauss (4.0). TVLA rho (0.01564952035907864).
# PollutionType.gauss (4.1000000000000005). TVLA rho (0.0030685617318876586).
# PollutionType.gauss (4.2). TVLA rho (0.032152365682259786).
# PollutionType.gauss (4.3). TVLA rho (0.019006318583638604).
# PollutionType.gauss (4.4). TVLA rho (0.010054573966644637).
# PollutionType.gauss (4.5). TVLA rho (0.042106996828878016).
# PollutionType.gauss (4.6000000000000005). TVLA rho (0.03588895833207757).
# PollutionType.gauss (4.7). TVLA rho (0.022430926431411407).
# PollutionType.gauss (4.800000000000001). TVLA rho (0.04571046298768646).
# PollutionType.gauss (4.9). TVLA rho (0.040018792143492375).
# PollutionType.gauss (5.0). TVLA rho (0.01901399851856746).
# PollutionType.desync (0). TVLA rho (5.799832986346423e-148).
# PollutionType.desync (5). TVLA rho (0.025053080951651194).
# PollutionType.desync (10). TVLA rho (0.1914135669206506).
# PollutionType.desync (15). TVLA rho (0.08327598762691792).
# PollutionType.desync (20). TVLA rho (0.06722223136795918).
# PollutionType.desync (25). TVLA rho (0.1767349007611525).
# PollutionType.desync (30). TVLA rho (0.33422427024795875).
# PollutionType.desync (35). TVLA rho (0.06648477089978908).
# PollutionType.desync (40). TVLA rho (0.04224450791520288).
# PollutionType.desync (45). TVLA rho (0.15660059616534608).
# PollutionType.desync (50). TVLA rho (0.04935442040130969).
# PollutionType.desync (55). TVLA rho (0.09474348623190533).
# PollutionType.desync (60). TVLA rho (0.21658486537332966).
# PollutionType.desync (65). TVLA rho (0.11406381794489101).
# PollutionType.desync (70). TVLA rho (0.05947665964286068).
# PollutionType.desync (75). TVLA rho (0.09722208560125739).
# PollutionType.desync (80). TVLA rho (0.051641319472250334).
# PollutionType.desync (85). TVLA rho (0.11574417962688605).
# PollutionType.desync (90). TVLA rho (0.0874940454717997).
# PollutionType.desync (95). TVLA rho (0.15183504136590847).
# PollutionType.desync (100). TVLA rho (0.13228999403698435).
# PollutionType.desync (105). TVLA rho (0.10156160665608768).
# PollutionType.desync (110). TVLA rho (0.24418779243137212).
# PollutionType.desync (115). TVLA rho (0.11114405614012013).
# PollutionType.desync (120). TVLA rho (0.10917190191382894).
# PollutionType.desync (125). TVLA rho (0.05748171701166821).
# PollutionType.desync (130). TVLA rho (0.14602032885568952).
# PollutionType.desync (135). TVLA rho (0.056314768655075176).
# PollutionType.desync (140). TVLA rho (0.10567298300426982).
# PollutionType.desync (145). TVLA rho (0.29545959630563645).
# PollutionType.desync (150). TVLA rho (0.1265867082545408).
# PollutionType.desync (155). TVLA rho (0.032595180195905196).
# PollutionType.desync (160). TVLA rho (0.07753747154455162).
# PollutionType.desync (165). TVLA rho (0.08635147976160291).
# PollutionType.desync (170). TVLA rho (0.06295347751209636).
# PollutionType.desync (175). TVLA rho (0.09525644134374585).
# PollutionType.desync (180). TVLA rho (0.09563748406657542).
# PollutionType.desync (185). TVLA rho (0.012946294980626787).
# PollutionType.desync (190). TVLA rho (0.2491920853260876).
# PollutionType.desync (195). TVLA rho (0.21931868877945715).
# PollutionType.desync (200). TVLA rho (0.08479009420855041).
# PollutionType.gauss (0). TVLA rho (1.3537018966509073e-134).
# PollutionType.gauss (2). TVLA rho (5.855506101530748e-103).
# PollutionType.gauss (4). TVLA rho (1.6225247494081707e-56).
# PollutionType.gauss (6). TVLA rho (4.162909702557079e-45).
# PollutionType.gauss (8). TVLA rho (2.515832963897253e-25).
# PollutionType.gauss (10). TVLA rho (2.4019965950061e-26).
# PollutionType.gauss (12). TVLA rho (1.6416150740109795e-17).
# PollutionType.gauss (14). TVLA rho (2.9778565606907234e-14).
# PollutionType.gauss (16). TVLA rho (1.4996531877456595e-12).
# PollutionType.gauss (18). TVLA rho (2.228537508420167e-12).
# PollutionType.gauss (20). TVLA rho (7.512499562535874e-11).
# PollutionType.gauss (22). TVLA rho (3.1048420243811996e-07).
# PollutionType.gauss (24). TVLA rho (3.866049499399434e-06).
# PollutionType.gauss (26). TVLA rho (0.0002881955152596367).
# PollutionType.gauss (28). TVLA rho (2.171883079526317e-06).
# PollutionType.gauss (30). TVLA rho (0.0001253790458604914).
# PollutionType.gauss (32). TVLA rho (0.0002737557333708117).
# PollutionType.gauss (34). TVLA rho (7.733571470205805e-05).
# PollutionType.gauss (36). TVLA rho (0.0004525934292268561).
# PollutionType.gauss (38). TVLA rho (3.4339399395882514e-05).
# PollutionType.gauss (40). TVLA rho (0.006047806210890913).
# PollutionType.gauss (42). TVLA rho (0.00010824793542944827).
# PollutionType.gauss (44). TVLA rho (9.00198436061903e-05).
# PollutionType.gauss (46). TVLA rho (0.00027080469135049777).
# PollutionType.gauss (48). TVLA rho (0.0054850150560786055).
# PollutionType.gauss (50). TVLA rho (0.016873326709957736).
# PollutionType.gauss (52). TVLA rho (0.014709459162554183).
# PollutionType.gauss (54). TVLA rho (0.021066170133389836).
# PollutionType.gauss (56). TVLA rho (0.00951838329129871).
# PollutionType.gauss (58). TVLA rho (0.0017306573493291637).
# PollutionType.gauss (60). TVLA rho (0.005241057770834004).
# PollutionType.gauss (62). TVLA rho (0.0164857880506124).
# PollutionType.gauss (64). TVLA rho (0.02291074860767441).
# PollutionType.gauss (66). TVLA rho (0.012039903573704692).
# PollutionType.gauss (68). TVLA rho (0.02447416680656805).
# PollutionType.gauss (70). TVLA rho (0.008913918238429706).
# PollutionType.gauss (72). TVLA rho (0.011750771426841444).
# PollutionType.gauss (74). TVLA rho (0.022979734710096168).
# PollutionType.gauss (76). TVLA rho (0.022687420499870357).
# PollutionType.gauss (78). TVLA rho (0.006031694217981565).
# PollutionType.gauss (80). TVLA rho (0.021041207656203067).
# PollutionType.gauss (82). TVLA rho (0.007010554216749443).
# PollutionType.gauss (84). TVLA rho (0.013740885850456805).
# PollutionType.gauss (86). TVLA rho (0.022712421830659905).
# PollutionType.gauss (88). TVLA rho (0.0050271766395350555).
# PollutionType.gauss (90). TVLA rho (0.005432946579580862).
# PollutionType.gauss (92). TVLA rho (0.006042327692955876).
# PollutionType.gauss (94). TVLA rho (0.03794929089720567).
# PollutionType.gauss (96). TVLA rho (0.032334184027601645).
# PollutionType.gauss (98). TVLA rho (0.03125568248734093).
# PollutionType.gauss (100). TVLA rho (0.011186678460353221).
# PollutionType.desync (0). TVLA rho (1.0478012299373584e-09).
# PollutionType.desync (10). TVLA rho (5.6333251604151656e-11).
# PollutionType.desync (20). TVLA rho (1.0935585015177209e-11).
# PollutionType.desync (30). TVLA rho (1.412628912681003e-09).
# PollutionType.desync (40). TVLA rho (1.1479414765710254e-07).
# PollutionType.desync (50). TVLA rho (4.566011360560234e-09).
# PollutionType.desync (60). TVLA rho (1.2389269075569772e-08).
# PollutionType.desync (70). TVLA rho (2.1663551167102743e-09).
# PollutionType.desync (80). TVLA rho (8.35571971143784e-11).
# PollutionType.desync (90). TVLA rho (2.494942431742955e-08).
# PollutionType.desync (100). TVLA rho (4.96122544318206e-07).
# PollutionType.desync (110). TVLA rho (1.4576756392484904e-08).
# PollutionType.desync (120). TVLA rho (8.179837771473848e-08).
# PollutionType.desync (130). TVLA rho (9.64710421153558e-07).
# PollutionType.desync (140). TVLA rho (1.0076939128780259e-07).
# PollutionType.desync (150). TVLA rho (6.761992127265027e-07).
# PollutionType.desync (160). TVLA rho (6.907816206836565e-08).
# PollutionType.desync (170). TVLA rho (3.593819944839202e-08).
# PollutionType.desync (180). TVLA rho (3.5268345096905193e-07).
# PollutionType.desync (190). TVLA rho (1.8421756169233512e-06).
# PollutionType.desync (200). TVLA rho (8.105760771125754e-06).
# PollutionType.desync (210). TVLA rho (1.3802495111744239e-05).
# PollutionType.desync (220). TVLA rho (3.5562361010089576e-08).
# PollutionType.desync (230). TVLA rho (3.628817113528683e-05).
# PollutionType.desync (240). TVLA rho (3.3858994445319055e-07).
# PollutionType.desync (250). TVLA rho (9.779824407899046e-06).
# PollutionType.desync (260). TVLA rho (3.431396951673636e-06).
# PollutionType.desync (270). TVLA rho (3.1104042034239485e-05).
# PollutionType.desync (280). TVLA rho (0.0001747336588392084).
# PollutionType.desync (290). TVLA rho (3.6452372574045863e-06).
# PollutionType.desync (300). TVLA rho (7.565129663458475e-05).
# PollutionType.desync (310). TVLA rho (3.7374898937203e-05).
# PollutionType.desync (320). TVLA rho (0.0017259817549602845).
# PollutionType.desync (330). TVLA rho (1.2517892789214221e-05).
# PollutionType.desync (340). TVLA rho (2.685140182378012e-05).
# PollutionType.desync (350). TVLA rho (0.000386245449948875).
# PollutionType.desync (360). TVLA rho (1.89927788260514e-06).
# PollutionType.desync (370). TVLA rho (0.00012454851029795156).
# PollutionType.desync (380). TVLA rho (0.0008005183958345144).
# PollutionType.desync (390). TVLA rho (2.3148454648303625e-06).
# PollutionType.desync (400). TVLA rho (1.3552178599743086e-05).
# PollutionType.desync (410). TVLA rho (0.0007696500861332209).
# PollutionType.desync (420). TVLA rho (4.847926068633125e-05).
# PollutionType.desync (430). TVLA rho (0.005260268539882674).
# PollutionType.desync (440). TVLA rho (0.0007715080744459957).
# PollutionType.desync (450). TVLA rho (0.01751950844354278).
# PollutionType.gauss (0). TVLA rho (2.2715103197937523e-11).
# PollutionType.gauss (100). TVLA rho (8.161434625064551e-09).
# PollutionType.gauss (200). TVLA rho (1.2165715270962023e-06).
# PollutionType.gauss (300). TVLA rho (4.590184600251065e-05).
# PollutionType.gauss (400). TVLA rho (0.00018197506954244165).
# PollutionType.gauss (500). TVLA rho (0.0007636699574127515).
# PollutionType.gauss (600). TVLA rho (0.00342024594756442).
# PollutionType.gauss (700). TVLA rho (0.0053205230151873355).
# PollutionType.gauss (800). TVLA rho (0.0006419102918005564).
# PollutionType.gauss (900). TVLA rho (0.019334923463253835).
# PollutionType.gauss (1000). TVLA rho (0.006509817308309926).
# PollutionType.gauss (1100). TVLA rho (0.012573833450098418).
# PollutionType.gauss (1200). TVLA rho (0.011611268342895806).
# PollutionType.gauss (1300). TVLA rho (0.01353894653409369).
# PollutionType.gauss (1400). TVLA rho (0.02039365474584935).
# PollutionType.gauss (1500). TVLA rho (0.011660056650625696).
# PollutionType.gauss (1600). TVLA rho (0.019606319356605284).
# PollutionType.gauss (1700). TVLA rho (0.0025040133836133354).
# PollutionType.gauss (1800). TVLA rho (0.0032257073984130508).
# PollutionType.gauss (1900). TVLA rho (0.027025386559239705).
# PollutionType.gauss (2000). TVLA rho (0.008144423034103303).
# PollutionType.gauss (2100). TVLA rho (0.007902811537508983).
# PollutionType.gauss (2200). TVLA rho (0.0040031039153447835).
# PollutionType.gauss (2300). TVLA rho (0.030860124582457467).
# PollutionType.gauss (2400). TVLA rho (0.0058212607310342964).
# PollutionType.gauss (2500). TVLA rho (0.021835474785516996).
# PollutionType.gauss (2600). TVLA rho (0.005810678094661393).
# PollutionType.gauss (2700). TVLA rho (0.016675389811900615).
# PollutionType.gauss (2800). TVLA rho (0.013920728191175886).
# PollutionType.gauss (2900). TVLA rho (0.006647968204842946).
# PollutionType.gauss (3000). TVLA rho (0.015395790931112223).
# PollutionType.gauss (3100). TVLA rho (0.025913700951207055).
# PollutionType.gauss (3200). TVLA rho (0.02710965832022739).
# PollutionType.gauss (3300). TVLA rho (0.033186318837770304).
# PollutionType.gauss (3400). TVLA rho (0.027192387323689584).
# PollutionType.gauss (3500). TVLA rho (0.01476335341431458).
# PollutionType.gauss (3600). TVLA rho (0.02118283984219682).
# PollutionType.gauss (3700). TVLA rho (0.011253190504979759).
# PollutionType.gauss (3800). TVLA rho (0.004226657339809495).
# PollutionType.gauss (3900). TVLA rho (0.02055086613615205).
# PollutionType.gauss (4000). TVLA rho (0.03742900186844891).
# PollutionType.desync (0.0). TVLA rho (0.07930043832492642).
# PollutionType.desync (0.05). TVLA rho (0.01781470524074884).
# PollutionType.desync (0.1). TVLA rho (0.026126652213935418).
# PollutionType.desync (0.15000000000000002). TVLA rho (0.015292328062911828).
# PollutionType.desync (0.2). TVLA rho (0.06505014445043868).
# PollutionType.desync (0.25). TVLA rho (0.09184493055408045).
# PollutionType.desync (0.30000000000000004). TVLA rho (0.025239659148271386).
# PollutionType.desync (0.35000000000000003). TVLA rho (0.02421406785631824).
# PollutionType.desync (0.4). TVLA rho (0.04891941883420307).
# PollutionType.desync (0.45). TVLA rho (0.039249596469958084).
# PollutionType.desync (0.5). TVLA rho (0.035001034280830484).
# PollutionType.desync (0.55). TVLA rho (0.08468264295559184).
# PollutionType.desync (0.6000000000000001). TVLA rho (0.007073420846164616).
# PollutionType.desync (0.65). TVLA rho (0.0188080718874892).
# PollutionType.desync (0.7000000000000001). TVLA rho (0.11217948315372082).
# PollutionType.desync (0.75). TVLA rho (0.03497148198681783).
# PollutionType.desync (0.8). TVLA rho (0.03037058434198096).
# PollutionType.desync (0.8500000000000001). TVLA rho (0.11562726098886852).
# PollutionType.desync (0.9). TVLA rho (0.02877554824554387).
# PollutionType.desync (0.9500000000000001). TVLA rho (0.10710335298390501).
# PollutionType.desync (1.0). TVLA rho (0.18566951493239403).
# PollutionType.desync (1.05). TVLA rho (0.0461169451708439).
# PollutionType.desync (1.1). TVLA rho (0.10882096534811951).
# PollutionType.desync (1.1500000000000001). TVLA rho (0.02735319797019503).
# PollutionType.desync (1.2000000000000002). TVLA rho (0.07660482072858803).
# PollutionType.desync (1.25). TVLA rho (0.050816989063503425).
# PollutionType.desync (1.3). TVLA rho (0.10206605720760771).
# PollutionType.desync (1.35). TVLA rho (0.08381680704324072).
# PollutionType.desync (1.4000000000000001). TVLA rho (0.02739118751779633).
# PollutionType.desync (1.4500000000000002). TVLA rho (0.06480668099645985).
# PollutionType.desync (1.5). TVLA rho (0.04475137904724588).
# PollutionType.desync (1.55). TVLA rho (0.017507979192149827).
# PollutionType.desync (1.6). TVLA rho (0.055958750801660365).
# PollutionType.desync (1.6500000000000001). TVLA rho (0.04516382237032403).
# PollutionType.desync (1.7000000000000002). TVLA rho (0.028622470387079747).
# PollutionType.desync (1.75). TVLA rho (0.015415868205838228).
# PollutionType.desync (1.8). TVLA rho (0.006181550433054734).
# PollutionType.desync (1.85). TVLA rho (0.1146032995721206).
# PollutionType.desync (1.9000000000000001). TVLA rho (0.0719112165671161).
# PollutionType.desync (1.9500000000000002). TVLA rho (0.04662055311385968).
# PollutionType.desync (2.0). TVLA rho (0.05468370023517004).
# PollutionType.gauss (0.0). TVLA rho (0.08221643536160231).
# PollutionType.gauss (0.1). TVLA rho (0.032051607733613895).
# PollutionType.gauss (0.2). TVLA rho (0.06350250761070272).
# PollutionType.gauss (0.30000000000000004). TVLA rho (0.05856402497014765).
# PollutionType.gauss (0.4). TVLA rho (0.01557948662155043).
# PollutionType.gauss (0.5). TVLA rho (0.03767820351563655).
# PollutionType.gauss (0.6000000000000001). TVLA rho (0.02114268839063989).
# PollutionType.gauss (0.7000000000000001). TVLA rho (0.02570563385946513).
# PollutionType.gauss (0.8). TVLA rho (0.02512298500209563).
# PollutionType.gauss (0.9). TVLA rho (0.019340977238667616).
# PollutionType.gauss (1.0). TVLA rho (0.0061199812949722186).
# PollutionType.gauss (1.1). TVLA rho (0.02953201928373816).
# PollutionType.gauss (1.2000000000000002). TVLA rho (0.03026624530696414).
# PollutionType.gauss (1.3). TVLA rho (0.03939599961777547).
# PollutionType.gauss (1.4000000000000001). TVLA rho (0.021514071649347367).
# PollutionType.gauss (1.5). TVLA rho (0.033403792644581445).
# PollutionType.gauss (1.6). TVLA rho (0.03342276521028465).
# PollutionType.gauss (1.7000000000000002). TVLA rho (0.040836113273407346).
# PollutionType.gauss (1.8). TVLA rho (0.010432786500492662).
# TVLA
